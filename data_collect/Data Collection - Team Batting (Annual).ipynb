# %% [markdown]
# ## Hello World

# %% [markdown]
# Sources:
# https://github.com/jldbc/pybaseball
# https://www.kaggle.com/code/weslayton/fangraphs-baseball-scraper-analysis

# %%
#import general libraries
import numpy as np
import pandas as pd

pd.set_option("display.precision", 2)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', 200)
pd.set_option('display.float_format', lambda x: '%.5f' % x)

from scipy import stats
import seaborn as sns

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('bmh')

# %%
#install latest pybaseball
#pip install pybaseball

# %%
#import data sources
import pybaseball

# %%
from pybaseball import batting_stats

# %% [markdown]
# ## Collect Data

# %% [markdown]
# ### Annual data

# %%
df = pybaseball.team_batting(2023,2023)

# %%
df.columns
# Out:
# Index(['teamIDfg', 'Season', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B',
#        ...
#        'maxEV', 'HardHit', 'HardHit%', 'Events', 'CStr%', 'CSW%', 'xBA',
#        'xSLG', 'xwOBA', 'L-WAR'],
#       dtype='object', length=319)

# %% [markdown]
# # Clean Data

# %%
print("Pre cleaning shape:", df.shape)
# Out:
# Pre cleaning shape: (30, 319)

# %%
df.head()
# Out:
#    teamIDfg  Season Team  Age    G    AB    PA    H   1B   2B  3B   HR    R  \
# 0        12    2023  TBR   28  996  2348  2641  615  365  126  11  113  395
# 1        13    2023  TEX   29  926  2315  2594  631  393  143   8   87  409
# 2        16    2023  ATL   29  931  2249  2505  591  360  117   5  109  339
# 3        22    2023  LAD   29  995  2251  2587  545  296  122  12  115  372
# 4        15    2023  ARI   28  971  2270  2542  600  371  136  16   77  348
#
#    RBI   BB  IBB   SO  HBP  SF  SH  GDP  SB  CS     AVG   GB   FB   LD  IFFB  \
# 0  378  235    1  585   37  17   4   41  89  18 0.26200  754  699  320    66
# 1  392  225    5  581   26  22   5   33  36  11 0.27300  710  667  373    55
# 2  327  216    9  559   26  14   0   58  47   9 0.26300  754  628  319    48
# 3  360  279   11  589   25  28   0   28  41  10 0.24200  630  705  354    65
# 4  333  211    4  502   21  23  13   49  63  12 0.26400  798  621  361    64
#
#    Pitches  Balls  Strikes  IFH  BU  BUH     BB%      K%    BB/K     OBP  \
# 0    10280   3710     6570   52  11    7 0.08900 0.22200 0.40000 0.33600
# 1    10089   3730     6359   54  11    3 0.08700 0.22400 0.39000 0.34100
# 2     9871   3578     6293   52   3    2 0.08600 0.22300 0.39000 0.33300
# 3    10303   3976     6327   36   1    0 0.10800 0.22800 0.47000 0.32900
# 4     9915   3638     6277   49  24    7 0.08300 0.19700 0.42000 0.33000
#
#       SLG     OPS     ISO   BABIP   GB/FB     LD%     GB%     FB%   IFFB%  \
# 0 0.46900 0.80600 0.20700 0.30100 1.08000 0.18000 0.42500 0.39400 0.09400
# 1 0.45400 0.79500 0.18100 0.32600 1.06000 0.21300 0.40600 0.38100 0.08200
# 2 0.46500 0.79700 0.20200 0.30200 1.20000 0.18800 0.44300 0.36900 0.07600
# 3 0.46000 0.78900 0.21800 0.27300 0.89000 0.21000 0.37300 0.41700 0.09200
# 4 0.44000 0.77000 0.17600 0.30500 1.29000 0.20300 0.44800 0.34900 0.10300
#
#     HR/FB    IFH%    BUH%    wOBA     wRAA  wRC      Bat      Fld      Rep  \
# 0 0.16200 0.06900 0.63600 0.34800 64.40000  383 86.70000 -0.70000 81.50000
# 1 0.13000 0.07600 0.27300 0.34400 54.60000  367 60.80000 16.40000 80.00000
# 2 0.17400 0.06900 0.66700 0.34400 52.00000  354 40.40000 -1.20000 77.30000
# 3 0.16300 0.05700 0.00000 0.33900 44.40000  356 45.50000 -0.90000 79.80000
# 4 0.12400 0.06100 0.29200 0.33300 31.10000  337 21.40000  6.60000 78.40000
#
#        Pos       RAR      WAR     Dol     Spd  wRC+      WPA      -WPA  \
# 0 -8.20000 176.30000 17.70000  $141.7 6.00000   128 10.54000 -37.85000
# 1 -8.20000 151.30000 15.20000  $121.7 4.90000   120  6.37000 -35.46000
# 2 -7.60000 113.60000 11.40000   $91.3 4.50000   113  5.75000 -42.91000
# 3 -7.50000 132.60000 13.30000  $106.6 5.00000   114  6.94000 -41.37000
# 4 -8.70000 111.60000 11.20000   $89.7 5.80000   107  7.70000 -40.41000
#
#       +WPA      RE24      REW     pLI    phLI  PH   WPA/LI   Clutch  \
# 0 48.40000 115.97000 12.78000 0.86000 1.70000  41 11.81000  0.42000
# 1 41.83000 126.94000 13.31000 0.83000 1.18000  32  6.91000  0.77000
# 2 48.67000  49.77000  5.14000 0.98000 1.35000  32  4.73000  1.13000
# 3 48.30000  86.49000  9.13000 0.95000 1.49000  70  7.55000 -0.26000
# 4 48.11000  53.33000  5.44000 0.93000 1.66000  57  3.85000  4.42000
#
#    FB% (Pitch)      FBv     SL%      SLv     CT%      CTv     CB%      CBv  \
# 0      0.45600 93.70000 0.23400 84.10000 0.08300 89.10000 0.07400 80.30000
# 1      0.49100 93.00000 0.20700 84.60000 0.08300 88.80000 0.10500 80.00000
# 2      0.47700 94.00000 0.20500 84.70000 0.07400 89.50000 0.09900 80.20000
# 3      0.47500 93.50000 0.21000 84.60000 0.08100 88.60000 0.10800 79.40000
# 4      0.48800 93.90000 0.23200 84.10000 0.07600 89.50000 0.08300 80.10000
#
#       CH%      CHv     SF%      SFv  KN%  KNv     XX%  PO%      wFB      wSL  \
# 0 0.13100 85.40000 0.02200 86.50000  NaN  NaN 0.00300  NaN 49.60000 13.80000
# 1 0.10000 85.30000 0.01500 87.40000  NaN  NaN 0.00300  NaN 23.40000 18.60000
# 2 0.12200 85.90000 0.02400 86.70000  NaN  NaN 0.00500  NaN 21.10000  3.00000
# 3 0.10900 86.10000 0.01700 88.10000  NaN  NaN 0.00600  NaN 23.70000 10.60000
# 4 0.10700 85.90000 0.01400 86.60000  NaN  NaN 0.00400  NaN 33.50000 -3.00000
#
#        wCT     wCB      wCH      wSF  wKN   wFB/C    wSL/C    wCT/C   wCB/C  \
# 0 -9.60000 3.30000  8.60000  1.10000  NaN 1.06000  0.58000 -1.13000 0.43000
# 1 -1.10000 4.50000 22.50000  1.90000  NaN 0.47000  0.89000 -0.14000 0.42000
# 2 11.30000 9.40000  1.00000 -4.30000  NaN 0.45000  0.15000  1.56000 0.96000
# 3 -2.10000 9.10000 21.00000 -3.60000  NaN 0.48000  0.49000 -0.25000 0.82000
# 4 -8.40000 5.10000  2.80000  2.00000  NaN 0.69000 -0.13000 -1.12000 0.63000
#
#     wCH/C  ...  KN% (pi)  SB% (pi)  SI% (pi)  SL% (pi)  XX% (pi)  vCH (pi)  \
# 0 0.64000  ...       NaN       NaN   0.15200   0.25100       NaN  85.80000
# 1 2.24000  ...       NaN       NaN   0.12700   0.22400       NaN  84.00000
# 2 0.08000  ...       NaN   0.00100   0.14100   0.21900       NaN  86.10000
# 3 1.88000  ...       NaN   0.00000   0.17900   0.21000   0.00000  86.00000
# 4 0.27000  ...       NaN   0.00100   0.16400   0.24400   0.00000  85.60000
#
#    vCS (pi)  vCU (pi)  vFA (pi)  vFC (pi)  vFS (pi)  vKN (pi)  vSB (pi)  \
# 0       NaN  80.10000  94.20000  89.40000  85.70000       NaN       NaN
# 1       NaN  80.00000  93.50000  89.90000  88.50000       NaN       NaN
# 2       NaN  80.20000  94.40000  90.00000  86.90000       NaN  81.90000
# 3  63.10000  79.40000  93.90000  89.20000  88.40000       NaN  80.20000
# 4  78.30000  80.00000  94.20000  89.70000  88.00000       NaN  81.30000
#
#    vSI (pi)  vSL (pi)  vXX (pi)  CH-X (pi)  CS-X (pi)  CU-X (pi)  FA-X (pi)  \
# 0  93.70000  84.40000       NaN   -4.80000        NaN    3.80000   -2.80000
# 1  93.60000  84.90000       NaN   -2.30000        NaN    2.60000   -1.90000
# 2  94.10000  85.00000       NaN   -2.60000        NaN    2.90000   -1.80000
# 3  93.20000  84.30000  78.50000   -2.70000    9.00000    3.30000   -1.90000
# 4  93.50000  84.30000  80.00000   -3.10000    4.90000    2.90000   -1.20000
#
#    FC-X (pi)  FS-X (pi)  KN-X (pi)  SB-X (pi)  SI-X (pi)  SL-X (pi)  \
# 0    0.80000   -5.00000        NaN        NaN   -5.60000    2.90000
# 1    0.80000   -4.60000        NaN        NaN   -3.00000    1.60000
# 2    1.00000   -5.70000        NaN   -6.50000   -4.40000    1.90000
# 3    0.40000   -6.30000        NaN   -5.00000   -3.20000    2.30000
# 4    0.80000   -5.90000        NaN   -6.60000   -3.80000    1.50000
#
#    XX-X (pi)  CH-Z (pi)  CS-Z (pi)  CU-Z (pi)  FA-Z (pi)  FC-Z (pi)  \
# 0        NaN    2.30000        NaN   -7.30000    8.70000    4.00000
# 1        NaN    2.60000        NaN   -7.50000    8.40000    4.10000
# 2        NaN    2.00000        NaN   -7.70000    8.40000    4.50000
# 3    0.00000    2.10000  -10.10000   -6.20000    8.20000    3.70000
# 4   -5.00000    2.40000   -9.60000   -6.70000    8.00000    3.80000
#
#    FS-Z (pi)  KN-Z (pi)  SB-Z (pi)  SI-Z (pi)  SL-Z (pi)  XX-Z (pi)  wCH (pi)  \
# 0    0.60000        NaN        NaN    3.60000   -0.40000        NaN   9.40000
# 1    1.30000        NaN        NaN    3.80000    0.10000        NaN  20.60000
# 2    0.90000        NaN   -4.10000    4.30000   -0.20000        NaN  -0.20000
# 3    1.20000        NaN   -4.60000    4.00000   -0.20000    0.00000  17.40000
# 4    1.10000        NaN   -3.30000    3.50000   -0.10000    3.50000   3.60000
#
#    wCS (pi)  wCU (pi)  wFA (pi)  wFC (pi)  wFS (pi)  wKN (pi)  wSB (pi)  \
# 0       NaN   3.70000  47.00000 -10.50000  -2.00000       NaN       NaN
# 1       NaN   2.10000  21.20000  -1.40000   3.50000       NaN       NaN
# 2       NaN  11.00000   8.10000  13.70000  -4.40000       NaN   0.30000
# 3  -0.30000   7.60000  16.40000  -4.50000  -1.20000       NaN  -0.50000
# 4   1.70000   3.70000  23.60000  -4.40000  -2.20000       NaN   1.70000
#
#    wSI (pi)  wSL (pi)  wXX (pi)  wCH/C (pi)  wCS/C (pi)  wCU/C (pi)  \
# 0   0.80000  12.70000       NaN     0.69000         NaN     0.59000
# 1  -0.90000  15.20000       NaN     1.97000         NaN     0.21000
# 2   6.60000  -4.50000       NaN    -0.01000         NaN     1.20000
# 3   5.70000  11.10000   0.00000     1.62000   -25.80000     0.73000
# 4   4.40000  -8.30000   0.00000     0.37000    11.39000     0.47000
#
#    wFA/C (pi)  wFC/C (pi)  wFS/C (pi)  wKN/C (pi)  wSB/C (pi)  wSI/C (pi)  \
# 0     1.52000    -1.26000    -0.96000         NaN         NaN     0.05000
# 1     0.61000    -0.16000     2.39000         NaN         NaN    -0.07000
# 2     0.25000     2.11000    -2.03000         NaN     5.29000     0.48000
# 3     0.55000    -0.45000    -0.61000         NaN   -12.67000     0.31000
# 4     0.75000    -0.63000    -1.05000         NaN    34.79000     0.27000
#
#    wSL/C (pi)  wXX/C (pi)  O-Swing% (pi)  Z-Swing% (pi)  Swing% (pi)  \
# 0     0.49000         NaN        0.29600        0.66500      0.48000
# 1     0.67000         NaN        0.26000        0.66700      0.46900
# 2    -0.21000         NaN        0.30000        0.69500      0.49700
# 3     0.52000    -4.40000        0.24700        0.64700      0.44600
# 4    -0.35000    -0.29000        0.26100        0.62300      0.44800
#
#    O-Contact% (pi)  Z-Contact% (pi)  Contact% (pi)  Zone% (pi)  Pace (pi)  \
# 0          0.54700          0.84300        0.75100     0.49700   18.70000
# 1          0.58200          0.85200        0.77900     0.51300   18.40000
# 2          0.59700          0.81500        0.74900     0.49800   18.70000
# 3          0.54200          0.84100        0.75700     0.49700   18.50000
# 4          0.59500          0.88600        0.80400     0.51700   18.60000
#
#        FRM  AVG+  BB%+  K%+  OBP+  SLG+  ISO+  BABIP+    LD+%  GB%+  FB%+  \
# 0 -5.90000   107   104   97   106   116   129     103 0.90000   101   104
# 1  4.50000   111   102   98   108   112   113     111 1.07000    96   101
# 2  8.00000   105    96   99   103   113   125     101 0.92000   104   100
# 3  0.60000    97   120  101   102   112   135      91 1.02000    87   114
# 4 -5.80000   106    93   88   102   107   109     102 0.99000   105    95
#
#    HR/FB%+  Pull%+  Cent%+  Oppo%+  Soft%+  Med%+  Hard%+       EV       LA  \
# 0      133     101     102      95      90    100     104 90.10000 13.50000
# 1      108      95     104     102      94     92     116 90.00000 13.20000
# 2      141     109      97      89      86     96     114 91.20000 11.90000
# 3      133     104      95     100      92     95     112 89.90000 15.90000
# 4      101     101     102      97      93    101     102 89.00000 11.10000
#
#    Barrels  Barrel%     maxEV  HardHit  HardHit%  Events   CStr%    CSW%  xBA  \
# 0      170  0.09500 114.50000      759   0.42500    1784 0.15800 0.27700  NaN
# 1      164  0.09300 115.10000      751   0.42600    1762 0.15900 0.26300  NaN
# 2      204  0.12000 118.60000      775   0.45500    1704 0.14100 0.26400  NaN
# 3      179  0.10600 112.70000      723   0.42700    1694 0.16900 0.27600  NaN
# 4      121  0.06700 114.30000      706   0.39000    1808 0.18300 0.27100  NaN
#
#    xSLG  xwOBA    L-WAR
# 0   NaN    NaN 17.50000
# 1   NaN    NaN 14.90000
# 2   NaN    NaN 10.50000
# 3   NaN    NaN 13.20000
# 4   NaN    NaN 11.60000
#
# [5 rows x 319 columns]

# %%
df.columns
# Out:
# Index(['teamIDfg', 'Season', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B',
#        ...
#        'maxEV', 'HardHit', 'HardHit%', 'Events', 'CStr%', 'CSW%', 'xBA',
#        'xSLG', 'xwOBA', 'L-WAR'],
#       dtype='object', length=319)

# %%
print("Pre removal ", df.shape)
#df = df.drop(['#days'], axis = 1)

print("Post removal ", df.shape)
# Out:
# Pre removal  (30, 319)
# Post removal  (30, 319)

# %%
df.columns
# Out:
# Index(['teamIDfg', 'Season', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B',
#        ...
#        'maxEV', 'HardHit', 'HardHit%', 'Events', 'CStr%', 'CSW%', 'xBA',
#        'xSLG', 'xwOBA', 'L-WAR'],
#       dtype='object', length=319)

# %%
# rename columns
#df = df.rename(columns = {'xyz': 'abc'})
#df.columns

# %%
# count nulls
counts = df.isna().sum()
percentages = round(df.isna().mean() * 100, 1)
null_values = pd.concat([counts, percentages], axis=1, keys=["count", "%"])
print(null_values)
# Out:
#                  count         %
# teamIDfg             0   0.00000
# Season               0   0.00000
# Team                 0   0.00000
# Age                  0   0.00000
# G                    0   0.00000
# AB                   0   0.00000
# PA                   0   0.00000
# H                    0   0.00000
# 1B                   0   0.00000
# 2B                   0   0.00000
# 3B                   0   0.00000
# HR                   0   0.00000
# R                    0   0.00000
# RBI                  0   0.00000
# BB                   0   0.00000
# IBB                  0   0.00000
# SO                   0   0.00000
# HBP                  0   0.00000
# SF                   0   0.00000
# SH                   0   0.00000
# GDP                  0   0.00000
# SB                   0   0.00000
# CS                   0   0.00000
# AVG                  0   0.00000
# GB                   0   0.00000
# FB                   0   0.00000
# LD                   0   0.00000
# IFFB                 0   0.00000
# Pitches              0   0.00000
# Balls                0   0.00000
# Strikes              0   0.00000
# IFH                  0   0.00000
# BU                   0   0.00000
# BUH                  0   0.00000
# BB%                  0   0.00000
# K%                   0   0.00000
# BB/K                 0   0.00000
# OBP                  0   0.00000
# SLG                  0   0.00000
# OPS                  0   0.00000
# ISO                  0   0.00000
# BABIP                0   0.00000
# GB/FB                0   0.00000
# LD%                  0   0.00000
# GB%                  0   0.00000
# FB%                  0   0.00000
# IFFB%                0   0.00000
# HR/FB                0   0.00000
# IFH%                 0   0.00000
# BUH%                 0   0.00000
# wOBA                 0   0.00000
# wRAA                 0   0.00000
# wRC                  0   0.00000
# Bat                  0   0.00000
# Fld                  0   0.00000
# Rep                  0   0.00000
# Pos                  0   0.00000
# RAR                  0   0.00000
# WAR                  0   0.00000
# Dol                  0   0.00000
# Spd                  0   0.00000
# wRC+                 0   0.00000
# WPA                  0   0.00000
# -WPA                 0   0.00000
# +WPA                 0   0.00000
# RE24                 0   0.00000
# REW                  0   0.00000
# pLI                  0   0.00000
# phLI                 0   0.00000
# PH                   0   0.00000
# WPA/LI               0   0.00000
# Clutch               0   0.00000
# FB% (Pitch)          0   0.00000
# FBv                  0   0.00000
# SL%                  0   0.00000
# SLv                  0   0.00000
# CT%                  0   0.00000
# CTv                  0   0.00000
# CB%                  0   0.00000
# CBv                  0   0.00000
# CH%                  0   0.00000
# CHv                  0   0.00000
# SF%                  0   0.00000
# SFv                  0   0.00000
# KN%                 27  90.00000
# KNv                 27  90.00000
# XX%                  0   0.00000
# PO%                 30 100.00000
# wFB                  0   0.00000
# wSL                  0   0.00000
# wCT                  0   0.00000
# wCB                  0   0.00000
# wCH                  0   0.00000
# wSF                  0   0.00000
# wKN                 27  90.00000
# wFB/C                0   0.00000
# wSL/C                0   0.00000
# wCT/C                0   0.00000
# wCB/C                0   0.00000
# wCH/C                0   0.00000
# wSF/C                0   0.00000
# wKN/C               27  90.00000
# O-Swing%             0   0.00000
# Z-Swing%             0   0.00000
# Swing%               0   0.00000
# O-Contact%           0   0.00000
# Z-Contact%           0   0.00000
# Contact%             0   0.00000
# Zone%                0   0.00000
# F-Strike%            0   0.00000
# SwStr%               0   0.00000
# BsR                  0   0.00000
# FA% (sc)             0   0.00000
# FT% (sc)            30 100.00000
# FC% (sc)             0   0.00000
# FS% (sc)             0   0.00000
# FO% (sc)            13  43.30000
# SI% (sc)             0   0.00000
# SL% (sc)             0   0.00000
# CU% (sc)             0   0.00000
# KC% (sc)             0   0.00000
# EP% (sc)            18  60.00000
# CH% (sc)             0   0.00000
# SC% (sc)            16  53.30000
# KN% (sc)            30 100.00000
# UN% (sc)            30 100.00000
# vFA (sc)             0   0.00000
# vFT (sc)            30 100.00000
# vFC (sc)             0   0.00000
# vFS (sc)             0   0.00000
# vFO (sc)            13  43.30000
# vSI (sc)             0   0.00000
# vSL (sc)             0   0.00000
# vCU (sc)             0   0.00000
# vKC (sc)             0   0.00000
# vEP (sc)            18  60.00000
# vCH (sc)             0   0.00000
# vSC (sc)            16  53.30000
# vKN (sc)            30 100.00000
# FA-X (sc)            0   0.00000
# FT-X (sc)           30 100.00000
# FC-X (sc)            0   0.00000
# FS-X (sc)            0   0.00000
# FO-X (sc)           13  43.30000
# SI-X (sc)            0   0.00000
# SL-X (sc)            0   0.00000
# CU-X (sc)            0   0.00000
# KC-X (sc)            0   0.00000
# EP-X (sc)           18  60.00000
# CH-X (sc)            0   0.00000
# SC-X (sc)           16  53.30000
# KN-X (sc)           30 100.00000
# FA-Z (sc)            0   0.00000
# FT-Z (sc)           30 100.00000
# FC-Z (sc)            0   0.00000
# FS-Z (sc)            0   0.00000
# FO-Z (sc)           13  43.30000
# SI-Z (sc)            0   0.00000
# SL-Z (sc)            0   0.00000
# CU-Z (sc)            0   0.00000
# KC-Z (sc)            0   0.00000
# EP-Z (sc)           18  60.00000
# CH-Z (sc)            0   0.00000
# SC-Z (sc)           16  53.30000
# KN-Z (sc)           30 100.00000
# wFA (sc)             0   0.00000
# wFT (sc)            30 100.00000
# wFC (sc)             0   0.00000
# wFS (sc)             0   0.00000
# wFO (sc)            13  43.30000
# wSI (sc)             0   0.00000
# wSL (sc)             0   0.00000
# wCU (sc)             0   0.00000
# wKC (sc)             0   0.00000
# wEP (sc)            18  60.00000
# wCH (sc)             0   0.00000
# wSC (sc)            16  53.30000
# wKN (sc)            30 100.00000
# wFA/C (sc)           0   0.00000
# wFT/C (sc)          30 100.00000
# wFC/C (sc)           0   0.00000
# wFS/C (sc)           0   0.00000
# wFO/C (sc)          13  43.30000
# wSI/C (sc)           0   0.00000
# wSL/C (sc)           0   0.00000
# wCU/C (sc)           0   0.00000
# wKC/C (sc)           0   0.00000
# wEP/C (sc)          18  60.00000
# wCH/C (sc)           0   0.00000
# wSC/C (sc)          16  53.30000
# wKN/C (sc)          30 100.00000
# O-Swing% (sc)        0   0.00000
# Z-Swing% (sc)        0   0.00000
# Swing% (sc)          0   0.00000
# O-Contact% (sc)      0   0.00000
# Z-Contact% (sc)      0   0.00000
# Contact% (sc)        0   0.00000
# Zone% (sc)           0   0.00000
# Pace                 0   0.00000
# Def                  0   0.00000
# wSB                  0   0.00000
# UBR                  0   0.00000
# Age Rng              0   0.00000
# Off                  0   0.00000
# Lg                   0   0.00000
# wGDP                 0   0.00000
# Pull%                0   0.00000
# Cent%                0   0.00000
# Oppo%                0   0.00000
# Soft%                0   0.00000
# Med%                 0   0.00000
# Hard%                0   0.00000
# TTO%                 0   0.00000
# CH% (pi)             0   0.00000
# CS% (pi)            23  76.70000
# CU% (pi)             0   0.00000
# FA% (pi)             0   0.00000
# FC% (pi)             0   0.00000
# FS% (pi)             0   0.00000
# KN% (pi)            30 100.00000
# SB% (pi)            17  56.70000
# SI% (pi)             0   0.00000
# SL% (pi)             0   0.00000
# XX% (pi)            14  46.70000
# vCH (pi)             0   0.00000
# vCS (pi)            23  76.70000
# vCU (pi)             0   0.00000
# vFA (pi)             0   0.00000
# vFC (pi)             0   0.00000
# vFS (pi)             0   0.00000
# vKN (pi)            30 100.00000
# vSB (pi)            17  56.70000
# vSI (pi)             0   0.00000
# vSL (pi)             0   0.00000
# vXX (pi)            14  46.70000
# CH-X (pi)            0   0.00000
# CS-X (pi)           23  76.70000
# CU-X (pi)            0   0.00000
# FA-X (pi)            0   0.00000
# FC-X (pi)            0   0.00000
# FS-X (pi)            0   0.00000
# KN-X (pi)           30 100.00000
# SB-X (pi)           17  56.70000
# SI-X (pi)            0   0.00000
# SL-X (pi)            0   0.00000
# XX-X (pi)           14  46.70000
# CH-Z (pi)            0   0.00000
# CS-Z (pi)           23  76.70000
# CU-Z (pi)            0   0.00000
# FA-Z (pi)            0   0.00000
# FC-Z (pi)            0   0.00000
# FS-Z (pi)            0   0.00000
# KN-Z (pi)           30 100.00000
# SB-Z (pi)           17  56.70000
# SI-Z (pi)            0   0.00000
# SL-Z (pi)            0   0.00000
# XX-Z (pi)           14  46.70000
# wCH (pi)             0   0.00000
# wCS (pi)            23  76.70000
# wCU (pi)             0   0.00000
# wFA (pi)             0   0.00000
# wFC (pi)             0   0.00000
# wFS (pi)             0   0.00000
# wKN (pi)            30 100.00000
# wSB (pi)            17  56.70000
# wSI (pi)             0   0.00000
# wSL (pi)             0   0.00000
# wXX (pi)            14  46.70000
# wCH/C (pi)           0   0.00000
# wCS/C (pi)          23  76.70000
# wCU/C (pi)           0   0.00000
# wFA/C (pi)           0   0.00000
# wFC/C (pi)           0   0.00000
# wFS/C (pi)           0   0.00000
# wKN/C (pi)          30 100.00000
# wSB/C (pi)          17  56.70000
# wSI/C (pi)           0   0.00000
# wSL/C (pi)           0   0.00000
# wXX/C (pi)          14  46.70000
# O-Swing% (pi)        0   0.00000
# Z-Swing% (pi)        0   0.00000
# Swing% (pi)          0   0.00000
# O-Contact% (pi)      0   0.00000
# Z-Contact% (pi)      0   0.00000
# Contact% (pi)        0   0.00000
# Zone% (pi)           0   0.00000
# Pace (pi)            0   0.00000
# FRM                  0   0.00000
# AVG+                 0   0.00000
# BB%+                 0   0.00000
# K%+                  0   0.00000
# OBP+                 0   0.00000
# SLG+                 0   0.00000
# ISO+                 0   0.00000
# BABIP+               0   0.00000
# LD+%                 0   0.00000
# GB%+                 0   0.00000
# FB%+                 0   0.00000
# HR/FB%+              0   0.00000
# Pull%+               0   0.00000
# Cent%+               0   0.00000
# Oppo%+               0   0.00000
# Soft%+               0   0.00000
# Med%+                0   0.00000
# Hard%+               0   0.00000
# EV                   0   0.00000
# LA                   0   0.00000
# Barrels              0   0.00000
# Barrel%              0   0.00000
# maxEV                0   0.00000
# HardHit              0   0.00000
# HardHit%             0   0.00000
# Events               0   0.00000
# CStr%                0   0.00000
# CSW%                 0   0.00000
# xBA                 30 100.00000
# xSLG                30 100.00000
# xwOBA               30 100.00000
# L-WAR                0   0.00000

# %%
# drop nulls
print("Pre removal ", df.shape)
#df = df.dropna()
print("Post removal ", df.shape)
# Out:
# Pre removal  (30, 319)
# Post removal  (30, 319)

# %%
# count duplicates
len(df['Team'])-len(df['Team'].drop_duplicates())
# Out:
# 0

# %%
# remove dups

print("Pre removal ", df.shape)
#df = df.drop_duplicates(subset=['Name'])
print("Post removal ", df.shape)
# Out:
# Pre removal  (30, 319)
# Post removal  (30, 319)

# %%
# remove outliers

#print("Pre removal ", df.shape)
#df = df[(np.abs(stats.zscore(df['xyz'])) < 3)]
#print("Post removal ", df.shape)

# %% [markdown]
# # Data Restructing

# %% [markdown]
# ## Variable Restructing

# %% [markdown]
# ### Level

# %%
# change column values
#df['Lev'] = df['Lev'].map({'Maj-AL': 'AL', 'Maj-NL': 'NL'})

# %%
# rename column
#df.rename(columns={'Lev': 'League'}, inplace=True)

# %%
# verify changes
#df[["League", "Name"]].groupby("League").count()

# %% [markdown]
# ## Normalizations

# %%
#df=['Volume_norm'] = (df.Volume - df.Volume.mean()) / (df.Volume.max() - df.Volume.mix())
#df.columns

# %% [markdown]
# ## Categorizations

# %%
#normalized = ['Volume_norm', 'Difficulty_norm']

# %% [markdown]
# ## Calculations

# %%
#calculate wOBA on 14 day player batting

#df['wOBA'] = (0.69*df['BB'] + 0.72*df['HBP'] + 0.89*df['H'] + 1.27*df['2B'] + 1.62*df['3B'] + 2.10*df['HR']) / (df['AB'] + df['BB'] - df['IBB'] + df['SF'] + df['HBP'])

# %%
#df.head()

# %% [markdown]
# ## Export Data

# %%
#EXPORT

df.to_csv('C:\\Users\\b7tbu\\JUPYTER PROJECTS\\ANALYTICO\\Data_Exports\\Team\\Batting\\EXPORT_annual.csv', index=False)
