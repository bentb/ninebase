# %% [markdown]
# ## Hello World

# %% [markdown]
# Sources:
# https://github.com/jldbc/pybaseball
# https://www.kaggle.com/code/weslayton/fangraphs-baseball-scraper-analysis

# %%
# !pip install scipy
# Out:
# Collecting scipy
#   Downloading scipy-1.11.1-cp310-cp310-win_amd64.whl (44.0 MB)
#                                               0.0/44.0 MB ? eta -:--:--
#                                               0.0/44.0 MB 1.9 MB/s eta 0:00:23
#                                               0.3/44.0 MB 3.9 MB/s eta 0:00:12
#                                               0.6/44.0 MB 4.7 MB/s eta 0:00:10
#      -                                        2.1/44.0 MB 12.0 MB/s eta 0:00:04
#      ---                                      3.9/44.0 MB 18.0 MB/s eta 0:00:03
#      ----                                     4.9/44.0 MB 18.2 MB/s eta 0:00:03
#      ------                                   7.5/44.0 MB 24.1 MB/s eta 0:00:02
#      --------                                 9.4/44.0 MB 26.1 MB/s eta 0:00:02
#      --------                                10.0/44.0 MB 24.7 MB/s eta 0:00:02
#      -----------                             13.5/44.0 MB 40.9 MB/s eta 0:00:01
#      ------------                            14.5/44.0 MB 40.9 MB/s eta 0:00:01
#      ---------------                         17.4/44.0 MB 40.9 MB/s eta 0:00:01
#      -----------------                       19.3/44.0 MB 40.9 MB/s eta 0:00:01
#      -------------------                     21.5/44.0 MB 46.7 MB/s eta 0:00:01
#      --------------------                    23.4/44.0 MB 40.9 MB/s eta 0:00:01
#      ----------------------                  25.3/44.0 MB 46.9 MB/s eta 0:00:01
#      ------------------------                27.3/44.0 MB 43.5 MB/s eta 0:00:01
#      -------------------------               29.2/44.0 MB 43.7 MB/s eta 0:00:01
#      ---------------------------             31.4/44.0 MB 46.9 MB/s eta 0:00:01
#      -----------------------------           33.3/44.0 MB 43.7 MB/s eta 0:00:01
#      -------------------------------         35.3/44.0 MB 43.7 MB/s eta 0:00:01
#      --------------------------------        37.2/44.0 MB 43.7 MB/s eta 0:00:01
#      ----------------------------------      39.2/44.0 MB 43.5 MB/s eta 0:00:01
#      ------------------------------------    40.8/44.0 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------    40.9/44.0 MB 40.9 MB/s eta 0:00:01
#      -------------------------------------   42.8/44.0 MB 34.6 MB/s eta 0:00:01
#      --------------------------------------  44.0/44.0 MB 34.4 MB/s eta 0:00:01
#      --------------------------------------  44.0/44.0 MB 34.4 MB/s eta 0:00:01
#      --------------------------------------  44.0/44.0 MB 34.4 MB/s eta 0:00:01
#      --------------------------------------- 44.0/44.0 MB 23.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from scipy) (1.25.0)
# Installing collected packages: scipy
# Successfully installed scipy-1.11.1

# %%
# !pip install pybaseball
# Out:
# Collecting pybaseball
#   Using cached pybaseball-2.2.5-py3-none-any.whl (419 kB)
# Requirement already satisfied: numpy>=1.13.0 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from pybaseball) (1.25.0)
# Requirement already satisfied: pandas>=1.0.3 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from pybaseball) (2.0.3)
# Requirement already satisfied: beautifulsoup4>=4.4.0 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from pybaseball) (4.12.2)
# Requirement already satisfied: requests>=2.18.1 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from pybaseball) (2.29.0)
# Requirement already satisfied: lxml>=4.2.1 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from pybaseball) (4.9.2)
# Requirement already satisfied: pyarrow>=1.0.1 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from pybaseball) (12.0.1)
# Collecting pygithub>=1.51 (from pybaseball)
#   Downloading PyGithub-1.59.0-py3-none-any.whl (342 kB)
#                                               0.0/342.1 kB ? eta -:--:--
#      ----------                              92.2/342.1 kB 5.5 MB/s eta 0:00:01
#      -------------------------------------- 342.1/342.1 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.4.0 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from pybaseball) (1.11.1)
# Requirement already satisfied: matplotlib>=2.0.0 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from pybaseball) (3.7.1)
# Requirement already satisfied: tqdm>=4.50.0 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from pybaseball) (4.65.0)
# Requirement already satisfied: attrs>=20.3.0 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from pybaseball) (22.1.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from beautifulsoup4>=4.4.0->pybaseball) (2.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from matplotlib>=2.0.0->pybaseball) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from matplotlib>=2.0.0->pybaseball) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from matplotlib>=2.0.0->pybaseball) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from matplotlib>=2.0.0->pybaseball) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from matplotlib>=2.0.0->pybaseball) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from matplotlib>=2.0.0->pybaseball) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from matplotlib>=2.0.0->pybaseball) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from matplotlib>=2.0.0->pybaseball) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from pandas>=1.0.3->pybaseball) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from pandas>=1.0.3->pybaseball) (2023.3)
# Collecting deprecated (from pygithub>=1.51->pybaseball)
#   Using cached Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting pyjwt[crypto]>=2.4.0 (from pygithub>=1.51->pybaseball)
#   Downloading PyJWT-2.7.0-py3-none-any.whl (22 kB)
# Collecting pynacl>=1.4.0 (from pygithub>=1.51->pybaseball)
#   Downloading PyNaCl-1.5.0-cp36-abi3-win_amd64.whl (212 kB)
#                                               0.0/212.1 kB ? eta -:--:--
#      ------------------------------------- 212.1/212.1 kB 13.5 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from requests>=2.18.1->pybaseball) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from requests>=2.18.1->pybaseball) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from requests>=2.18.1->pybaseball) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from requests>=2.18.1->pybaseball) (2023.5.7)
# Requirement already satisfied: colorama in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from tqdm>=4.50.0->pybaseball) (0.4.6)
# Requirement already satisfied: cryptography>=3.4.0 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from pyjwt[crypto]>=2.4.0->pygithub>=1.51->pybaseball) (39.0.1)
# Requirement already satisfied: cffi>=1.4.1 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from pynacl>=1.4.0->pygithub>=1.51->pybaseball) (1.15.1)
# Requirement already satisfied: six>=1.5 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.0.0->pybaseball) (1.16.0)
# Collecting wrapt<2,>=1.10 (from deprecated->pygithub>=1.51->pybaseball)
#   Downloading wrapt-1.15.0-cp310-cp310-win_amd64.whl (36 kB)
# Requirement already satisfied: pycparser in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from cffi>=1.4.1->pynacl>=1.4.0->pygithub>=1.51->pybaseball) (2.21)
# Installing collected packages: wrapt, pyjwt, pynacl, deprecated, pygithub, pybaseball
# Successfully installed deprecated-1.2.14 pybaseball-2.2.5 pygithub-1.59.0 pyjwt-2.7.0 pynacl-1.5.0 wrapt-1.15.0

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from seaborn) (1.25.0)
# Requirement already satisfied: pandas>=0.25 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from seaborn) (2.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from pandas>=0.25->seaborn) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)

# %%
#import general libraries
import numpy as np
import pandas as pd

pd.set_option("display.precision", 2)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', 200)
pd.set_option('display.float_format', lambda x: '%.5f' % x)

from scipy import stats
import seaborn as sns

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('bmh')

# %%
#install latest pybaseball
# !pip install --upgrade pybaseball
# Out:
# Requirement already satisfied: pybaseball in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (2.2.5)
# Requirement already satisfied: numpy>=1.13.0 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from pybaseball) (1.25.0)
# Requirement already satisfied: pandas>=1.0.3 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from pybaseball) (2.0.3)
# Requirement already satisfied: beautifulsoup4>=4.4.0 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from pybaseball) (4.12.2)
# Requirement already satisfied: requests>=2.18.1 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from pybaseball) (2.29.0)
# Requirement already satisfied: lxml>=4.2.1 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from pybaseball) (4.9.2)
# Requirement already satisfied: pyarrow>=1.0.1 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from pybaseball) (12.0.1)
# Requirement already satisfied: pygithub>=1.51 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from pybaseball) (1.59.0)
# Requirement already satisfied: scipy>=1.4.0 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from pybaseball) (1.11.1)
# Requirement already satisfied: matplotlib>=2.0.0 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from pybaseball) (3.7.1)
# Requirement already satisfied: tqdm>=4.50.0 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from pybaseball) (4.65.0)
# Requirement already satisfied: attrs>=20.3.0 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from pybaseball) (22.1.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from beautifulsoup4>=4.4.0->pybaseball) (2.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from matplotlib>=2.0.0->pybaseball) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from matplotlib>=2.0.0->pybaseball) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from matplotlib>=2.0.0->pybaseball) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from matplotlib>=2.0.0->pybaseball) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from matplotlib>=2.0.0->pybaseball) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from matplotlib>=2.0.0->pybaseball) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from matplotlib>=2.0.0->pybaseball) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from matplotlib>=2.0.0->pybaseball) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from pandas>=1.0.3->pybaseball) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from pandas>=1.0.3->pybaseball) (2023.3)
# Requirement already satisfied: deprecated in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from pygithub>=1.51->pybaseball) (1.2.14)
# Requirement already satisfied: pyjwt[crypto]>=2.4.0 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from pygithub>=1.51->pybaseball) (2.7.0)
# Requirement already satisfied: pynacl>=1.4.0 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from pygithub>=1.51->pybaseball) (1.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from requests>=2.18.1->pybaseball) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from requests>=2.18.1->pybaseball) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from requests>=2.18.1->pybaseball) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from requests>=2.18.1->pybaseball) (2023.5.7)
# Requirement already satisfied: colorama in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from tqdm>=4.50.0->pybaseball) (0.4.6)
# Requirement already satisfied: cryptography>=3.4.0 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from pyjwt[crypto]>=2.4.0->pygithub>=1.51->pybaseball) (39.0.1)
# Requirement already satisfied: cffi>=1.4.1 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from pynacl>=1.4.0->pygithub>=1.51->pybaseball) (1.15.1)
# Requirement already satisfied: six>=1.5 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.0.0->pybaseball) (1.16.0)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from deprecated->pygithub>=1.51->pybaseball) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\b7tbu\anaconda3\envs\ninebase\lib\site-packages (from cffi>=1.4.1->pynacl>=1.4.0->pygithub>=1.51->pybaseball) (2.21)

# %%
#import data sources
import pybaseball

# %%
from pybaseball import batting_stats

# %% [markdown]
# ## Collect Data

# %% [markdown]
# ### Annual data

# %%
df = pybaseball.batting_stats(2023,2023)

# %%
df.columns
# Out:
# Index(['IDfg', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B',
#        ...
#        'maxEV', 'HardHit', 'HardHit%', 'Events', 'CStr%', 'CSW%', 'xBA',
#        'xSLG', 'xwOBA', 'L-WAR'],
#       dtype='object', length=320)

# %% [markdown]
# # Clean Data

# %%
print("Pre cleaning shape:", df.shape)
# Out:
# Pre cleaning shape: (151, 320)

# %%
df.head()
# Out:
#      IDfg  Season              Name Team  Age   G   AB   PA    H  1B  2B  3B  \
# 1   18401    2023  Ronald Acuna Jr.  ATL   25  86  347  396  117  71  24   1
# 0   19755    2023     Shohei Ohtani  LAA   28  87  334  389   99  48  15   5
# 6   13611    2023      Mookie Betts  LAD   30  84  325  386   88  42  22   1
# 57  23667    2023     Wander Franco  TBR   22  83  331  366   94  59  21   4
# 7   25878    2023    Corbin Carroll  ARI   22  83  297  335   86  45  20   3
#
#     HR   R  RBI  BB  IBB  SO  HBP  SF  SH  GDP  SB  CS     AVG   GB   FB  LD  \
# 1   21  78   54  43    2  49    4   2   0    7  41   7 0.33700  150   91  59
# 0   31  61   68  47    4  86    1   2   0    7  11   4 0.29600  110  102  38
# 6   23  68   57  52    0  64    4   5   0    4   7   2 0.27100   79  130  57
# 57  10  47   43  29    2  49    2   4   0   12  28   8 0.28400  138   79  69
# 7   18  61   46  30    1  66    6   1   1    3  24   2 0.29000  105   85  38
#
#     IFFB  Pitches  Balls  Strikes  IFH  BU  BUH     BB%      K%    BB/K  \
# 1      6     1528    617      911   16   0    0 0.10900 0.12400 0.88000
# 0      6     1541    604      937    7   0    0 0.12100 0.22100 0.55000
# 6     12     1482    620      862    5   0    0 0.13500 0.16600 0.81000
# 57     8     1419    526      893    7   0    0 0.07900 0.13400 0.59000
# 7      9     1293    487      806    6   5    2 0.09000 0.19700 0.45000
#
#        OBP     SLG     OPS     ISO   BABIP   GB/FB     LD%     GB%     FB%  \
# 1  0.41400 0.59400 1.00800 0.25600 0.34400 0.01650 0.19700 0.50000 0.30300
# 0  0.38300 0.65000 1.03300 0.35300 0.31100 0.01080 0.15200 0.44000 0.40800
# 6  0.37300 0.55700 0.93000 0.28600 0.26700 0.00610 0.21400 0.29700 0.48900
# 57 0.34200 0.46200 0.80400 0.17800 0.30400 0.01750 0.24100 0.48300 0.27600
# 7  0.36500 0.55900 0.92400 0.26900 0.31800 0.01240 0.16700 0.46100 0.37300
#
#      IFFB%   HR/FB    IFH%    BUH%    wOBA     wRAA  wRC      Bat     Fld  \
# 1  0.06600 0.23100 0.10700 0.00000 0.42700 35.50000   83 33.50000 0.30000
# 0  0.05900 0.30400 0.06400 0.00000 0.42700 34.90000   82 35.20000     NaN
# 6  0.09200 0.17700 0.06300 0.00000 0.39300 23.80000   71 23.80000 0.30000
# 57 0.10100 0.12700 0.05100 0.00000 0.34400  7.70000   52 11.00000 9.20000
# 7  0.10600 0.21200 0.05700 0.40000 0.39200 20.30000   61 18.80000 0.70000
#
#         Rep      Pos      RAR     WAR    Dol     Spd  wRC+     WPA     -WPA  \
# 1  12.20000 -3.90000 48.70000 4.90000  $39.0 6.80000   168 3.67000 -5.24000
# 0  12.00000 -9.40000 39.50000 4.00000  $31.7 6.20000   177 2.92000 -6.26000
# 6  11.90000 -1.70000 38.10000 3.80000  $30.6 4.90000   150 2.73000 -5.84000
# 57 11.30000  3.50000 38.00000 3.80000  $30.5 7.20000   125 0.59000 -5.56000
# 7  10.40000 -2.60000 36.50000 3.70000  $29.3 8.30000   145 2.81000 -4.71000
#
#       +WPA     RE24     REW     pLI    phLI  PH  WPA/LI   Clutch  FB% (Pitch)  \
# 1  8.91000 42.05000 4.33000 0.90000     NaN   0 3.65000  0.43000      0.50100
# 0  9.18000 36.48000 3.81000 1.03000     NaN   0 3.71000 -0.88000      0.40600
# 6  8.56000 28.67000 2.91000 0.97000 1.14000   1 2.89000 -0.07000      0.53500
# 57 6.15000 13.35000 1.49000 0.89000 1.46000   2 1.37000 -0.70000      0.41200
# 7  7.52000 26.36000 2.75000 0.98000 1.30000   3 2.64000  0.24000      0.46300
#
#         FBv     SL%      SLv     CT%      CTv     CB%      CBv     CH%  \
# 1  93.70000 0.23200 85.10000 0.06200 89.30000 0.08200 80.00000 0.09600
# 0  94.50000 0.21700 84.60000 0.10800 89.70000 0.08600 80.30000 0.14100
# 6  94.00000 0.23100 84.80000 0.08100 88.50000 0.07100 79.90000 0.06500
# 57 93.80000 0.17400 84.50000 0.09100 89.30000 0.09300 80.50000 0.19900
# 7  94.00000 0.21300 83.80000 0.10000 90.60000 0.10000 80.20000 0.10100
#
#         CHv     SF%      SFv  KN%  KNv     XX%  PO%      wFB      wSL  \
# 1  85.40000 0.02700 85.00000  NaN  NaN 0.00800  NaN 17.40000 11.30000
# 0  86.20000 0.04200 87.50000  NaN  NaN 0.01400  NaN 12.90000  6.90000
# 6  86.20000 0.01800 89.20000  NaN  NaN 0.00300  NaN 16.30000  6.80000
# 57 85.70000 0.03100 87.30000  NaN  NaN 0.00800  NaN 11.00000  5.10000
# 7  86.60000 0.02400 86.20000  NaN  NaN 0.00400  NaN 20.40000  3.70000
#
#         wCT      wCB      wCH      wSF  wKN   wFB/C   wSL/C    wCT/C    wCB/C  \
# 1   1.00000  6.40000 -0.90000  2.30000  NaN 2.28000 3.20000  1.09000  5.09000
# 0   3.50000  4.50000  5.00000  1.20000  NaN 2.07000 2.08000  2.12000  3.43000
# 6  -0.20000  2.40000  1.80000 -0.70000  NaN 2.06000 1.99000 -0.21000  2.33000
# 57 -1.50000 -2.00000 -0.90000 -2.20000  NaN 1.89000 2.07000 -1.17000 -1.54000
# 7  -3.00000 -0.20000 -1.20000  1.10000  NaN 3.41000 1.36000 -2.30000 -0.14000
#
#     ...  KN% (pi)  SB% (pi)  SI% (pi)  SL% (pi)  XX% (pi)  vCH (pi)  vCS (pi)  \
# 1   ...       NaN   0.00100   0.19800   0.23700       NaN  85.40000       NaN
# 0   ...       NaN       NaN   0.10200   0.24000       NaN  86.30000       NaN
# 6   ...       NaN   0.00100   0.21400   0.23400       NaN  86.10000       NaN
# 57  ...       NaN       NaN   0.12100   0.18500       NaN  86.00000       NaN
# 7   ...       NaN   0.00200   0.14600   0.23000       NaN  86.20000  77.40000
#
#     vCU (pi)  vFA (pi)  vFC (pi)  vFS (pi)  vKN (pi)  vSB (pi)  vSI (pi)  \
# 1   79.60000  94.10000  89.60000  84.80000       NaN  81.90000  94.40000
# 0   80.10000  94.60000  90.70000  87.00000       NaN       NaN  94.10000
# 6   79.90000  94.40000  88.90000  88.30000       NaN  80.10000  93.50000
# 57  80.60000  94.10000  89.70000  87.00000       NaN       NaN  93.80000
# 7   80.00000  94.30000  90.80000  87.30000       NaN  82.80000  93.50000
#
#     vSL (pi)  vXX (pi)  CH-X (pi)  CS-X (pi)  CU-X (pi)  FA-X (pi)  FC-X (pi)  \
# 1   85.30000       NaN   -1.50000        NaN    2.90000   -1.90000    0.70000
# 0   84.70000       NaN   -7.30000        NaN    3.50000   -1.70000    1.20000
# 6   84.70000       NaN   -1.60000        NaN    2.80000   -2.10000    0.80000
# 57  84.50000       NaN   -5.60000        NaN    3.40000   -2.30000    1.00000
# 7   84.10000       NaN   -6.80000    7.00000    5.20000   -2.20000    0.80000
#
#     FS-X (pi)  KN-X (pi)  SB-X (pi)  SI-X (pi)  SL-X (pi)  XX-X (pi)  \
# 1    -4.70000        NaN   -6.60000   -6.80000    2.30000        NaN
# 0    -6.70000        NaN        NaN   -1.80000    0.60000        NaN
# 6    -6.10000        NaN   -5.30000   -4.50000    3.20000        NaN
# 57   -6.90000        NaN        NaN   -4.20000    2.80000        NaN
# 7    -5.90000        NaN   -8.30000   -3.20000    1.20000        NaN
#
#     CH-Z (pi)  CS-Z (pi)  CU-Z (pi)  FA-Z (pi)  FC-Z (pi)  FS-Z (pi)  \
# 1     2.50000        NaN   -7.30000    8.20000    3.90000    0.50000
# 0     2.80000        NaN   -7.20000    8.50000    3.90000    0.70000
# 6     2.30000        NaN   -6.30000    8.20000    3.60000    1.30000
# 57    2.10000        NaN   -7.80000    8.60000    4.20000    1.10000
# 7     2.10000  -10.50000   -6.90000    8.10000    4.40000    1.20000
#
#     KN-Z (pi)  SB-Z (pi)  SI-Z (pi)  SL-Z (pi)  XX-Z (pi)  wCH (pi)  wCS (pi)  \
# 1         NaN   -4.10000    4.20000    0.10000        NaN  -0.30000       NaN
# 0         NaN        NaN    4.10000   -0.40000        NaN   4.10000       NaN
# 6         NaN   -2.30000    3.90000    0.10000        NaN  -0.20000       NaN
# 57        NaN        NaN    4.00000   -0.50000        NaN  -2.00000       NaN
# 7         NaN   -2.40000    3.10000    0.00000        NaN  -1.20000   0.00000
#
#     wCU (pi)  wFA (pi)  wFC (pi)  wFS (pi)  wKN (pi)  wSB (pi)  wSI (pi)  \
# 1    4.10000  12.80000   0.90000   2.00000       NaN   0.10000   3.90000
# 0    4.50000   6.50000   1.90000   1.50000       NaN       NaN   5.40000
# 6    2.20000   7.40000  -1.00000   0.30000       NaN  -0.20000  10.30000
# 57  -1.20000   9.10000  -0.40000  -1.30000       NaN       NaN   1.40000
# 7    0.00000  10.80000  -2.40000  -0.10000       NaN   1.30000   8.90000
#
#     wSL (pi)  wXX (pi)  wCH/C (pi)  wCS/C (pi)  wCU/C (pi)  wFA/C (pi)  \
# 1   10.50000       NaN    -0.20000         NaN     3.34000     2.87000
# 0    7.90000       NaN     1.92000         NaN     3.53000     1.44000
# 6    7.80000       NaN    -0.25000         NaN     2.29000     1.58000
# 57   3.30000       NaN    -0.69000         NaN    -1.04000     2.24000
# 7    3.20000       NaN    -1.00000     3.61000     0.04000     2.71000
#
#     wFC/C (pi)  wFS/C (pi)  wKN/C (pi)  wSB/C (pi)  wSI/C (pi)  wSL/C (pi)  \
# 1      0.96000     4.97000         NaN     4.27000     1.31000     2.93000
# 0      1.21000     2.36000         NaN         NaN     3.45000     2.15000
# 6     -0.78000     1.07000         NaN   -15.92000     3.26000     2.26000
# 57    -0.30000    -3.63000         NaN         NaN     0.84000     1.26000
# 7     -1.96000    -0.19000         NaN    62.60000     4.71000     1.09000
#
#     wXX/C (pi)  O-Swing% (pi)  Z-Swing% (pi)  Swing% (pi)  O-Contact% (pi)  \
# 1          NaN        0.22600        0.67500      0.45600          0.65100
# 0          NaN        0.29700        0.67900      0.47900          0.51900
# 6          NaN        0.17200        0.59200      0.38100          0.54300
# 57         NaN        0.25600        0.60900      0.44500          0.76300
# 7          NaN        0.27700        0.62500      0.44800          0.69800
#
#     Z-Contact% (pi)  Contact% (pi)  Zone% (pi)  Pace (pi)  FRM  AVG+  BB%+  \
# 1           0.87700        0.82200     0.51200   18.10000  NaN   134   122
# 0           0.80800        0.71400     0.47500   18.70000  NaN   121   144
# 6           0.93100        0.84300     0.49800   17.70000  NaN   108   152
# 57          0.91600        0.87500     0.53500   18.80000  NaN   116    95
# 7           0.86600        0.81300     0.49100   18.40000  NaN   115   101
#
#     K%+  OBP+  SLG+  ISO+  BABIP+    LD+%  GB%+  FB%+  HR/FB%+  Pull%+  \
# 1    55   128   143   157     114 0.97000   116    82      184     112
# 0    97   121   160   220     105 0.76000   104   108      252      97
# 6    74   115   134   176      89 1.06000    69   133      141     117
# 57   59   108   114   111     103 1.20000   115    73      105     102
# 7    88   113   135   165     106 0.82000   107   101      169     107
#
#     Cent%+  Oppo%+  Soft%+  Med%+  Hard%+       EV       LA  Barrels  Barrel%  \
# 1       97      85      64     89     135 94.90000  7.80000       47  0.15700
# 0      103     102      65     95     124 93.70000 13.10000       46  0.18000
# 6      102      69      63     90     134 92.40000 19.60000       32  0.12000
# 57     101      96      91     97     109 88.90000  8.30000       18  0.06300
# 7       88     105      77    107     100 90.70000 11.80000       22  0.09400
#
#        maxEV  HardHit  HardHit%  Events   CStr%    CSW%     xBA    xSLG  \
# 1  116.70000      165   0.55000     300 0.14000 0.22100 0.35400 0.65900
# 0  117.10000      130   0.51000     255 0.13000 0.26500 0.29100 0.64100
# 6  110.10000      129   0.48500     266 0.20000 0.26100 0.28000 0.55700
# 57 111.00000      112   0.39200     286 0.18200 0.23700 0.29200 0.45100
# 7  113.80000      101   0.43300     233 0.17500 0.25900 0.26100 0.45300
#
#      xwOBA   L-WAR
# 1  0.46100 4.80000
# 0  0.42600 4.00000
# 6  0.40300 3.80000
# 57 0.34900 3.10000
# 7  0.34700 3.50000
#
# [5 rows x 320 columns]

# %%
df.columns
# Out:
# Index(['IDfg', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B',
#        ...
#        'maxEV', 'HardHit', 'HardHit%', 'Events', 'CStr%', 'CSW%', 'xBA',
#        'xSLG', 'xwOBA', 'L-WAR'],
#       dtype='object', length=320)

# %%
print("Pre removal ", df.shape)
#df = df.drop(['#days'], axis = 1)

print("Post removal ", df.shape)
# Out:
# Pre removal  (151, 320)
# Post removal  (151, 320)

# %%
df.columns
# Out:
# Index(['IDfg', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B',
#        ...
#        'maxEV', 'HardHit', 'HardHit%', 'Events', 'CStr%', 'CSW%', 'xBA',
#        'xSLG', 'xwOBA', 'L-WAR'],
#       dtype='object', length=320)

# %%
# rename columns
#df = df.rename(columns = {'xyz': 'abc'})
#df.columns

# %%
# count nulls
counts = df.isna().sum()
percentages = round(df.isna().mean() * 100, 1)
null_values = pd.concat([counts, percentages], axis=1, keys=["count", "%"])
print(null_values)
# Out:
#                  count         %
# IDfg                 0   0.00000
# Season               0   0.00000
# Name                 0   0.00000
# Team                 0   0.00000
# Age                  0   0.00000
# G                    0   0.00000
# AB                   0   0.00000
# PA                   0   0.00000
# H                    0   0.00000
# 1B                   0   0.00000
# 2B                   0   0.00000
# 3B                   0   0.00000
# HR                   0   0.00000
# R                    0   0.00000
# RBI                  0   0.00000
# BB                   0   0.00000
# IBB                  0   0.00000
# SO                   0   0.00000
# HBP                  0   0.00000
# SF                   0   0.00000
# SH                   0   0.00000
# GDP                  0   0.00000
# SB                   0   0.00000
# CS                   0   0.00000
# AVG                  0   0.00000
# GB                   0   0.00000
# FB                   0   0.00000
# LD                   0   0.00000
# IFFB                 0   0.00000
# Pitches              0   0.00000
# Balls                0   0.00000
# Strikes              0   0.00000
# IFH                  0   0.00000
# BU                   0   0.00000
# BUH                  0   0.00000
# BB%                  0   0.00000
# K%                   0   0.00000
# BB/K                 0   0.00000
# OBP                  0   0.00000
# SLG                  0   0.00000
# OPS                  0   0.00000
# ISO                  0   0.00000
# BABIP                0   0.00000
# GB/FB                0   0.00000
# LD%                  0   0.00000
# GB%                  0   0.00000
# FB%                  0   0.00000
# IFFB%                0   0.00000
# HR/FB                0   0.00000
# IFH%                 0   0.00000
# BUH%                 0   0.00000
# wOBA                 0   0.00000
# wRAA                 0   0.00000
# wRC                  0   0.00000
# Bat                  0   0.00000
# Fld                  2   1.30000
# Rep                  0   0.00000
# Pos                  0   0.00000
# RAR                  0   0.00000
# WAR                  0   0.00000
# Dol                  0   0.00000
# Spd                  0   0.00000
# wRC+                 0   0.00000
# WPA                  0   0.00000
# -WPA                 0   0.00000
# +WPA                 0   0.00000
# RE24                 0   0.00000
# REW                  0   0.00000
# pLI                  0   0.00000
# phLI                43  28.50000
# PH                   0   0.00000
# WPA/LI               0   0.00000
# Clutch               0   0.00000
# FB% (Pitch)          0   0.00000
# FBv                  0   0.00000
# SL%                  0   0.00000
# SLv                  0   0.00000
# CT%                  0   0.00000
# CTv                  0   0.00000
# CB%                  0   0.00000
# CBv                  0   0.00000
# CH%                  0   0.00000
# CHv                  0   0.00000
# SF%                  0   0.00000
# SFv                  0   0.00000
# KN%                147  97.40000
# KNv                147  97.40000
# XX%                  2   1.30000
# PO%                151 100.00000
# wFB                  0   0.00000
# wSL                  0   0.00000
# wCT                  0   0.00000
# wCB                  0   0.00000
# wCH                  0   0.00000
# wSF                  0   0.00000
# wKN                147  97.40000
# wFB/C                0   0.00000
# wSL/C                0   0.00000
# wCT/C                0   0.00000
# wCB/C                0   0.00000
# wCH/C                0   0.00000
# wSF/C                0   0.00000
# wKN/C              147  97.40000
# O-Swing%             0   0.00000
# Z-Swing%             0   0.00000
# Swing%               0   0.00000
# O-Contact%           0   0.00000
# Z-Contact%           0   0.00000
# Contact%             0   0.00000
# Zone%                0   0.00000
# F-Strike%            0   0.00000
# SwStr%               0   0.00000
# BsR                  0   0.00000
# FA% (sc)             0   0.00000
# FT% (sc)           151 100.00000
# FC% (sc)             0   0.00000
# FS% (sc)             0   0.00000
# FO% (sc)            67  44.40000
# SI% (sc)             0   0.00000
# SL% (sc)             0   0.00000
# CU% (sc)             0   0.00000
# KC% (sc)             0   0.00000
# EP% (sc)           117  77.50000
# CH% (sc)             0   0.00000
# SC% (sc)           130  86.10000
# KN% (sc)           147  97.40000
# UN% (sc)           151 100.00000
# vFA (sc)             0   0.00000
# vFT (sc)           151 100.00000
# vFC (sc)             0   0.00000
# vFS (sc)             0   0.00000
# vFO (sc)            67  44.40000
# vSI (sc)             0   0.00000
# vSL (sc)             0   0.00000
# vCU (sc)             0   0.00000
# vKC (sc)             0   0.00000
# vEP (sc)           117  77.50000
# vCH (sc)             0   0.00000
# vSC (sc)           130  86.10000
# vKN (sc)           147  97.40000
# FA-X (sc)            0   0.00000
# FT-X (sc)          151 100.00000
# FC-X (sc)            0   0.00000
# FS-X (sc)            0   0.00000
# FO-X (sc)           67  44.40000
# SI-X (sc)            0   0.00000
# SL-X (sc)            0   0.00000
# CU-X (sc)            0   0.00000
# KC-X (sc)            0   0.00000
# EP-X (sc)          117  77.50000
# CH-X (sc)            0   0.00000
# SC-X (sc)          130  86.10000
# KN-X (sc)          147  97.40000
# FA-Z (sc)            0   0.00000
# FT-Z (sc)          151 100.00000
# FC-Z (sc)            0   0.00000
# FS-Z (sc)            0   0.00000
# FO-Z (sc)           67  44.40000
# SI-Z (sc)            0   0.00000
# SL-Z (sc)            0   0.00000
# CU-Z (sc)            0   0.00000
# KC-Z (sc)            0   0.00000
# EP-Z (sc)          117  77.50000
# CH-Z (sc)            0   0.00000
# SC-Z (sc)          130  86.10000
# KN-Z (sc)          147  97.40000
# wFA (sc)             0   0.00000
# wFT (sc)           151 100.00000
# wFC (sc)             0   0.00000
# wFS (sc)             0   0.00000
# wFO (sc)            67  44.40000
# wSI (sc)             0   0.00000
# wSL (sc)             0   0.00000
# wCU (sc)             0   0.00000
# wKC (sc)             0   0.00000
# wEP (sc)           117  77.50000
# wCH (sc)             0   0.00000
# wSC (sc)           130  86.10000
# wKN (sc)           147  97.40000
# wFA/C (sc)           0   0.00000
# wFT/C (sc)         151 100.00000
# wFC/C (sc)           0   0.00000
# wFS/C (sc)           0   0.00000
# wFO/C (sc)          67  44.40000
# wSI/C (sc)           0   0.00000
# wSL/C (sc)           0   0.00000
# wCU/C (sc)           0   0.00000
# wKC/C (sc)           0   0.00000
# wEP/C (sc)         117  77.50000
# wCH/C (sc)           0   0.00000
# wSC/C (sc)         130  86.10000
# wKN/C (sc)         147  97.40000
# O-Swing% (sc)        0   0.00000
# Z-Swing% (sc)        0   0.00000
# Swing% (sc)          0   0.00000
# O-Contact% (sc)      0   0.00000
# Z-Contact% (sc)      0   0.00000
# Contact% (sc)        0   0.00000
# Zone% (sc)           0   0.00000
# Pace                 0   0.00000
# Def                  0   0.00000
# wSB                  0   0.00000
# UBR                  0   0.00000
# Age Rng              0   0.00000
# Off                  0   0.00000
# Lg                   0   0.00000
# wGDP                 0   0.00000
# Pull%                0   0.00000
# Cent%                0   0.00000
# Oppo%                0   0.00000
# Soft%                0   0.00000
# Med%                 0   0.00000
# Hard%                0   0.00000
# TTO%                 0   0.00000
# CH% (pi)             0   0.00000
# CS% (pi)           124  82.10000
# CU% (pi)             0   0.00000
# FA% (pi)             0   0.00000
# FC% (pi)             0   0.00000
# FS% (pi)             0   0.00000
# KN% (pi)           147  97.40000
# SB% (pi)           130  86.10000
# SI% (pi)             0   0.00000
# SL% (pi)             0   0.00000
# XX% (pi)           131  86.80000
# vCH (pi)             0   0.00000
# vCS (pi)           124  82.10000
# vCU (pi)             0   0.00000
# vFA (pi)             0   0.00000
# vFC (pi)             0   0.00000
# vFS (pi)             0   0.00000
# vKN (pi)           147  97.40000
# vSB (pi)           130  86.10000
# vSI (pi)             0   0.00000
# vSL (pi)             0   0.00000
# vXX (pi)           131  86.80000
# CH-X (pi)            0   0.00000
# CS-X (pi)          124  82.10000
# CU-X (pi)            0   0.00000
# FA-X (pi)            0   0.00000
# FC-X (pi)            0   0.00000
# FS-X (pi)            0   0.00000
# KN-X (pi)          147  97.40000
# SB-X (pi)          130  86.10000
# SI-X (pi)            0   0.00000
# SL-X (pi)            0   0.00000
# XX-X (pi)          131  86.80000
# CH-Z (pi)            0   0.00000
# CS-Z (pi)          124  82.10000
# CU-Z (pi)            0   0.00000
# FA-Z (pi)            0   0.00000
# FC-Z (pi)            0   0.00000
# FS-Z (pi)            0   0.00000
# KN-Z (pi)          147  97.40000
# SB-Z (pi)          130  86.10000
# SI-Z (pi)            0   0.00000
# SL-Z (pi)            0   0.00000
# XX-Z (pi)          131  86.80000
# wCH (pi)             0   0.00000
# wCS (pi)           124  82.10000
# wCU (pi)             0   0.00000
# wFA (pi)             0   0.00000
# wFC (pi)             0   0.00000
# wFS (pi)             0   0.00000
# wKN (pi)           147  97.40000
# wSB (pi)           130  86.10000
# wSI (pi)             0   0.00000
# wSL (pi)             0   0.00000
# wXX (pi)           131  86.80000
# wCH/C (pi)           0   0.00000
# wCS/C (pi)         124  82.10000
# wCU/C (pi)           0   0.00000
# wFA/C (pi)           0   0.00000
# wFC/C (pi)           0   0.00000
# wFS/C (pi)           0   0.00000
# wKN/C (pi)         147  97.40000
# wSB/C (pi)         130  86.10000
# wSI/C (pi)           0   0.00000
# wSL/C (pi)           0   0.00000
# wXX/C (pi)         131  86.80000
# O-Swing% (pi)        0   0.00000
# Z-Swing% (pi)        0   0.00000
# Swing% (pi)          0   0.00000
# O-Contact% (pi)      0   0.00000
# Z-Contact% (pi)      0   0.00000
# Contact% (pi)        0   0.00000
# Zone% (pi)           0   0.00000
# Pace (pi)            0   0.00000
# FRM                138  91.40000
# AVG+                 0   0.00000
# BB%+                 0   0.00000
# K%+                  0   0.00000
# OBP+                 0   0.00000
# SLG+                 0   0.00000
# ISO+                 0   0.00000
# BABIP+               0   0.00000
# LD+%                 0   0.00000
# GB%+                 0   0.00000
# FB%+                 0   0.00000
# HR/FB%+              0   0.00000
# Pull%+               0   0.00000
# Cent%+               0   0.00000
# Oppo%+               0   0.00000
# Soft%+               0   0.00000
# Med%+                0   0.00000
# Hard%+               0   0.00000
# EV                   0   0.00000
# LA                   0   0.00000
# Barrels              0   0.00000
# Barrel%              0   0.00000
# maxEV                0   0.00000
# HardHit              0   0.00000
# HardHit%             0   0.00000
# Events               0   0.00000
# CStr%                0   0.00000
# CSW%                 0   0.00000
# xBA                  0   0.00000
# xSLG                 0   0.00000
# xwOBA                0   0.00000
# L-WAR                0   0.00000

# %%
# drop nulls
print("Pre removal ", df.shape)
#df = df.dropna()
print("Post removal ", df.shape)
# Out:
# Pre removal  (151, 320)
# Post removal  (151, 320)

# %%
# count duplicates
len(df['Name'])-len(df['Name'].drop_duplicates())
# Out:
# 0

# %%
# remove dups

print("Pre removal ", df.shape)
#df = df.drop_duplicates(subset=['Name'])
print("Post removal ", df.shape)
# Out:
# Pre removal  (151, 320)
# Post removal  (151, 320)

# %%
# remove outliers

#print("Pre removal ", df.shape)
#df = df[(np.abs(stats.zscore(df['xyz'])) < 3)]
#print("Post removal ", df.shape)

# %% [markdown]
# # Data Restructing

# %% [markdown]
# ## Variable Restructing

# %% [markdown]
# ### Level

# %%
# change column values
#df['Lev'] = df['Lev'].map({'Maj-AL': 'AL', 'Maj-NL': 'NL'})

# %%
# rename column
#df.rename(columns={'Lev': 'League'}, inplace=True)

# %%
# verify changes
#df[["League", "Name"]].groupby("League").count()

# %% [markdown]
# ## Round Values

# %%
df.head()
# Out:
#      IDfg  Season              Name Team  Age   G   AB   PA    H  1B  2B  3B  \
# 1   18401    2023  Ronald Acuna Jr.  ATL   25  86  347  396  117  71  24   1
# 0   19755    2023     Shohei Ohtani  LAA   28  87  334  389   99  48  15   5
# 6   13611    2023      Mookie Betts  LAD   30  84  325  386   88  42  22   1
# 57  23667    2023     Wander Franco  TBR   22  83  331  366   94  59  21   4
# 7   25878    2023    Corbin Carroll  ARI   22  83  297  335   86  45  20   3
#
#     HR   R  RBI  BB  IBB  SO  HBP  SF  SH  GDP  SB  CS     AVG   GB   FB  LD  \
# 1   21  78   54  43    2  49    4   2   0    7  41   7 0.33700  150   91  59
# 0   31  61   68  47    4  86    1   2   0    7  11   4 0.29600  110  102  38
# 6   23  68   57  52    0  64    4   5   0    4   7   2 0.27100   79  130  57
# 57  10  47   43  29    2  49    2   4   0   12  28   8 0.28400  138   79  69
# 7   18  61   46  30    1  66    6   1   1    3  24   2 0.29000  105   85  38
#
#     IFFB  Pitches  Balls  Strikes  IFH  BU  BUH     BB%      K%    BB/K  \
# 1      6     1528    617      911   16   0    0 0.10900 0.12400 0.88000
# 0      6     1541    604      937    7   0    0 0.12100 0.22100 0.55000
# 6     12     1482    620      862    5   0    0 0.13500 0.16600 0.81000
# 57     8     1419    526      893    7   0    0 0.07900 0.13400 0.59000
# 7      9     1293    487      806    6   5    2 0.09000 0.19700 0.45000
#
#        OBP     SLG     OPS     ISO   BABIP   GB/FB     LD%     GB%     FB%  \
# 1  0.41400 0.59400 1.00800 0.25600 0.34400 0.01650 0.19700 0.50000 0.30300
# 0  0.38300 0.65000 1.03300 0.35300 0.31100 0.01080 0.15200 0.44000 0.40800
# 6  0.37300 0.55700 0.93000 0.28600 0.26700 0.00610 0.21400 0.29700 0.48900
# 57 0.34200 0.46200 0.80400 0.17800 0.30400 0.01750 0.24100 0.48300 0.27600
# 7  0.36500 0.55900 0.92400 0.26900 0.31800 0.01240 0.16700 0.46100 0.37300
#
#      IFFB%   HR/FB    IFH%    BUH%    wOBA     wRAA  wRC      Bat     Fld  \
# 1  0.06600 0.23100 0.10700 0.00000 0.42700 35.50000   83 33.50000 0.30000
# 0  0.05900 0.30400 0.06400 0.00000 0.42700 34.90000   82 35.20000     NaN
# 6  0.09200 0.17700 0.06300 0.00000 0.39300 23.80000   71 23.80000 0.30000
# 57 0.10100 0.12700 0.05100 0.00000 0.34400  7.70000   52 11.00000 9.20000
# 7  0.10600 0.21200 0.05700 0.40000 0.39200 20.30000   61 18.80000 0.70000
#
#         Rep      Pos      RAR     WAR    Dol     Spd  wRC+     WPA     -WPA  \
# 1  12.20000 -3.90000 48.70000 4.90000  $39.0 6.80000   168 3.67000 -5.24000
# 0  12.00000 -9.40000 39.50000 4.00000  $31.7 6.20000   177 2.92000 -6.26000
# 6  11.90000 -1.70000 38.10000 3.80000  $30.6 4.90000   150 2.73000 -5.84000
# 57 11.30000  3.50000 38.00000 3.80000  $30.5 7.20000   125 0.59000 -5.56000
# 7  10.40000 -2.60000 36.50000 3.70000  $29.3 8.30000   145 2.81000 -4.71000
#
#       +WPA     RE24     REW     pLI    phLI  PH  WPA/LI   Clutch  FB% (Pitch)  \
# 1  8.91000 42.05000 4.33000 0.90000     NaN   0 3.65000  0.43000      0.50100
# 0  9.18000 36.48000 3.81000 1.03000     NaN   0 3.71000 -0.88000      0.40600
# 6  8.56000 28.67000 2.91000 0.97000 1.14000   1 2.89000 -0.07000      0.53500
# 57 6.15000 13.35000 1.49000 0.89000 1.46000   2 1.37000 -0.70000      0.41200
# 7  7.52000 26.36000 2.75000 0.98000 1.30000   3 2.64000  0.24000      0.46300
#
#         FBv     SL%      SLv     CT%      CTv     CB%      CBv     CH%  \
# 1  93.70000 0.23200 85.10000 0.06200 89.30000 0.08200 80.00000 0.09600
# 0  94.50000 0.21700 84.60000 0.10800 89.70000 0.08600 80.30000 0.14100
# 6  94.00000 0.23100 84.80000 0.08100 88.50000 0.07100 79.90000 0.06500
# 57 93.80000 0.17400 84.50000 0.09100 89.30000 0.09300 80.50000 0.19900
# 7  94.00000 0.21300 83.80000 0.10000 90.60000 0.10000 80.20000 0.10100
#
#         CHv     SF%      SFv  KN%  KNv     XX%  PO%      wFB      wSL  \
# 1  85.40000 0.02700 85.00000  NaN  NaN 0.00800  NaN 17.40000 11.30000
# 0  86.20000 0.04200 87.50000  NaN  NaN 0.01400  NaN 12.90000  6.90000
# 6  86.20000 0.01800 89.20000  NaN  NaN 0.00300  NaN 16.30000  6.80000
# 57 85.70000 0.03100 87.30000  NaN  NaN 0.00800  NaN 11.00000  5.10000
# 7  86.60000 0.02400 86.20000  NaN  NaN 0.00400  NaN 20.40000  3.70000
#
#         wCT      wCB      wCH      wSF  wKN   wFB/C   wSL/C    wCT/C    wCB/C  \
# 1   1.00000  6.40000 -0.90000  2.30000  NaN 2.28000 3.20000  1.09000  5.09000
# 0   3.50000  4.50000  5.00000  1.20000  NaN 2.07000 2.08000  2.12000  3.43000
# 6  -0.20000  2.40000  1.80000 -0.70000  NaN 2.06000 1.99000 -0.21000  2.33000
# 57 -1.50000 -2.00000 -0.90000 -2.20000  NaN 1.89000 2.07000 -1.17000 -1.54000
# 7  -3.00000 -0.20000 -1.20000  1.10000  NaN 3.41000 1.36000 -2.30000 -0.14000
#
#     ...  KN% (pi)  SB% (pi)  SI% (pi)  SL% (pi)  XX% (pi)  vCH (pi)  vCS (pi)  \
# 1   ...       NaN   0.00100   0.19800   0.23700       NaN  85.40000       NaN
# 0   ...       NaN       NaN   0.10200   0.24000       NaN  86.30000       NaN
# 6   ...       NaN   0.00100   0.21400   0.23400       NaN  86.10000       NaN
# 57  ...       NaN       NaN   0.12100   0.18500       NaN  86.00000       NaN
# 7   ...       NaN   0.00200   0.14600   0.23000       NaN  86.20000  77.40000
#
#     vCU (pi)  vFA (pi)  vFC (pi)  vFS (pi)  vKN (pi)  vSB (pi)  vSI (pi)  \
# 1   79.60000  94.10000  89.60000  84.80000       NaN  81.90000  94.40000
# 0   80.10000  94.60000  90.70000  87.00000       NaN       NaN  94.10000
# 6   79.90000  94.40000  88.90000  88.30000       NaN  80.10000  93.50000
# 57  80.60000  94.10000  89.70000  87.00000       NaN       NaN  93.80000
# 7   80.00000  94.30000  90.80000  87.30000       NaN  82.80000  93.50000
#
#     vSL (pi)  vXX (pi)  CH-X (pi)  CS-X (pi)  CU-X (pi)  FA-X (pi)  FC-X (pi)  \
# 1   85.30000       NaN   -1.50000        NaN    2.90000   -1.90000    0.70000
# 0   84.70000       NaN   -7.30000        NaN    3.50000   -1.70000    1.20000
# 6   84.70000       NaN   -1.60000        NaN    2.80000   -2.10000    0.80000
# 57  84.50000       NaN   -5.60000        NaN    3.40000   -2.30000    1.00000
# 7   84.10000       NaN   -6.80000    7.00000    5.20000   -2.20000    0.80000
#
#     FS-X (pi)  KN-X (pi)  SB-X (pi)  SI-X (pi)  SL-X (pi)  XX-X (pi)  \
# 1    -4.70000        NaN   -6.60000   -6.80000    2.30000        NaN
# 0    -6.70000        NaN        NaN   -1.80000    0.60000        NaN
# 6    -6.10000        NaN   -5.30000   -4.50000    3.20000        NaN
# 57   -6.90000        NaN        NaN   -4.20000    2.80000        NaN
# 7    -5.90000        NaN   -8.30000   -3.20000    1.20000        NaN
#
#     CH-Z (pi)  CS-Z (pi)  CU-Z (pi)  FA-Z (pi)  FC-Z (pi)  FS-Z (pi)  \
# 1     2.50000        NaN   -7.30000    8.20000    3.90000    0.50000
# 0     2.80000        NaN   -7.20000    8.50000    3.90000    0.70000
# 6     2.30000        NaN   -6.30000    8.20000    3.60000    1.30000
# 57    2.10000        NaN   -7.80000    8.60000    4.20000    1.10000
# 7     2.10000  -10.50000   -6.90000    8.10000    4.40000    1.20000
#
#     KN-Z (pi)  SB-Z (pi)  SI-Z (pi)  SL-Z (pi)  XX-Z (pi)  wCH (pi)  wCS (pi)  \
# 1         NaN   -4.10000    4.20000    0.10000        NaN  -0.30000       NaN
# 0         NaN        NaN    4.10000   -0.40000        NaN   4.10000       NaN
# 6         NaN   -2.30000    3.90000    0.10000        NaN  -0.20000       NaN
# 57        NaN        NaN    4.00000   -0.50000        NaN  -2.00000       NaN
# 7         NaN   -2.40000    3.10000    0.00000        NaN  -1.20000   0.00000
#
#     wCU (pi)  wFA (pi)  wFC (pi)  wFS (pi)  wKN (pi)  wSB (pi)  wSI (pi)  \
# 1    4.10000  12.80000   0.90000   2.00000       NaN   0.10000   3.90000
# 0    4.50000   6.50000   1.90000   1.50000       NaN       NaN   5.40000
# 6    2.20000   7.40000  -1.00000   0.30000       NaN  -0.20000  10.30000
# 57  -1.20000   9.10000  -0.40000  -1.30000       NaN       NaN   1.40000
# 7    0.00000  10.80000  -2.40000  -0.10000       NaN   1.30000   8.90000
#
#     wSL (pi)  wXX (pi)  wCH/C (pi)  wCS/C (pi)  wCU/C (pi)  wFA/C (pi)  \
# 1   10.50000       NaN    -0.20000         NaN     3.34000     2.87000
# 0    7.90000       NaN     1.92000         NaN     3.53000     1.44000
# 6    7.80000       NaN    -0.25000         NaN     2.29000     1.58000
# 57   3.30000       NaN    -0.69000         NaN    -1.04000     2.24000
# 7    3.20000       NaN    -1.00000     3.61000     0.04000     2.71000
#
#     wFC/C (pi)  wFS/C (pi)  wKN/C (pi)  wSB/C (pi)  wSI/C (pi)  wSL/C (pi)  \
# 1      0.96000     4.97000         NaN     4.27000     1.31000     2.93000
# 0      1.21000     2.36000         NaN         NaN     3.45000     2.15000
# 6     -0.78000     1.07000         NaN   -15.92000     3.26000     2.26000
# 57    -0.30000    -3.63000         NaN         NaN     0.84000     1.26000
# 7     -1.96000    -0.19000         NaN    62.60000     4.71000     1.09000
#
#     wXX/C (pi)  O-Swing% (pi)  Z-Swing% (pi)  Swing% (pi)  O-Contact% (pi)  \
# 1          NaN        0.22600        0.67500      0.45600          0.65100
# 0          NaN        0.29700        0.67900      0.47900          0.51900
# 6          NaN        0.17200        0.59200      0.38100          0.54300
# 57         NaN        0.25600        0.60900      0.44500          0.76300
# 7          NaN        0.27700        0.62500      0.44800          0.69800
#
#     Z-Contact% (pi)  Contact% (pi)  Zone% (pi)  Pace (pi)  FRM  AVG+  BB%+  \
# 1           0.87700        0.82200     0.51200   18.10000  NaN   134   122
# 0           0.80800        0.71400     0.47500   18.70000  NaN   121   144
# 6           0.93100        0.84300     0.49800   17.70000  NaN   108   152
# 57          0.91600        0.87500     0.53500   18.80000  NaN   116    95
# 7           0.86600        0.81300     0.49100   18.40000  NaN   115   101
#
#     K%+  OBP+  SLG+  ISO+  BABIP+    LD+%  GB%+  FB%+  HR/FB%+  Pull%+  \
# 1    55   128   143   157     114 0.97000   116    82      184     112
# 0    97   121   160   220     105 0.76000   104   108      252      97
# 6    74   115   134   176      89 1.06000    69   133      141     117
# 57   59   108   114   111     103 1.20000   115    73      105     102
# 7    88   113   135   165     106 0.82000   107   101      169     107
#
#     Cent%+  Oppo%+  Soft%+  Med%+  Hard%+       EV       LA  Barrels  Barrel%  \
# 1       97      85      64     89     135 94.90000  7.80000       47  0.15700
# 0      103     102      65     95     124 93.70000 13.10000       46  0.18000
# 6      102      69      63     90     134 92.40000 19.60000       32  0.12000
# 57     101      96      91     97     109 88.90000  8.30000       18  0.06300
# 7       88     105      77    107     100 90.70000 11.80000       22  0.09400
#
#        maxEV  HardHit  HardHit%  Events   CStr%    CSW%     xBA    xSLG  \
# 1  116.70000      165   0.55000     300 0.14000 0.22100 0.35400 0.65900
# 0  117.10000      130   0.51000     255 0.13000 0.26500 0.29100 0.64100
# 6  110.10000      129   0.48500     266 0.20000 0.26100 0.28000 0.55700
# 57 111.00000      112   0.39200     286 0.18200 0.23700 0.29200 0.45100
# 7  113.80000      101   0.43300     233 0.17500 0.25900 0.26100 0.45300
#
#      xwOBA   L-WAR
# 1  0.46100 4.80000
# 0  0.42600 4.00000
# 6  0.40300 3.80000
# 57 0.34900 3.10000
# 7  0.34700 3.50000
#
# [5 rows x 320 columns]

# %% [markdown]
# ## Normalizations

# %%
#df=['Volume_norm'] = (df.Volume - df.Volume.mean()) / (df.Volume.max() - df.Volume.mix())
#df.columns

# %% [markdown]
# ## Calculations

# %%
#calculate wOBA on 14 day player batting

#df['wOBA'] = (0.69*df['BB'] + 0.72*df['HBP'] + 0.89*df['H'] + 1.27*df['2B'] + 1.62*df['3B'] + 2.10*df['HR']) / (df['AB'] + df['BB'] - df['IBB'] + df['SF'] + df['HBP'])

# %%
#df.head()

# %% [markdown]
# ## Categorizations

# %%
#normalized = ['Volume_norm', 'Difficulty_norm']

# %% [markdown]
# ## Export Data

# %%
#EXPORT

df.to_csv('C:\\Users\\b7tbu\\NINEBASE\\ninebase\\data_storage\\player_batting_season.csv', index=False)
