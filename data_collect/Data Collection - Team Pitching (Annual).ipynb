# %% [markdown]
# ## Hello World

# %% [markdown]
# Sources:
# https://github.com/jldbc/pybaseball
# https://www.kaggle.com/code/weslayton/fangraphs-baseball-scraper-analysis

# %%
#import general libraries
import numpy as np
import pandas as pd

pd.set_option("display.precision", 2)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', 200)
pd.set_option('display.float_format', lambda x: '%.5f' % x)

from scipy import stats
import seaborn as sns

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('bmh')

# %%
#install latest pybaseball
#pip install pybaseball

# %%
#import data sources
import pybaseball

# %%
from pybaseball import batting_stats

# %% [markdown]
# ## Collect Data

# %% [markdown]
# ### Annual data

# %%
df = pybaseball.team_pitching(2023,2023)

# %%
df.columns
# Out:
# Index(['teamIDfg', 'Season', 'Team', 'Age', 'W', 'L', 'ERA', 'G', 'GS', 'CG',
#        ...
#        'LA', 'Barrels', 'Barrel%', 'maxEV', 'HardHit', 'HardHit%', 'Events',
#        'CStr%', 'CSW%', 'xERA'],
#       dtype='object', length=333)

# %% [markdown]
# # Clean Data

# %%
print("Pre cleaning shape:", df.shape)
# Out:
# Pre cleaning shape: (30, 333)

# %%
df.head()
# Out:
#    teamIDfg  Season Team  Age   W   L     ERA    G  GS  CG  ShO  SV  BS  \
# 0        21    2023  HOU   29  38  29 3.30000  271  67   1    1  17   8
# 1         8    2023  MIN   28  34  33 3.54000  264  67   0    0  13  14
# 2        12    2023  TBR   29  48  22 3.56000  297  70   0    0  20  14
# 3         9    2023  NYY   29  39  29 3.60000  281  68   1    1  20   8
# 4        29    2023  SDP   30  32  34 3.76000  268  66   0    0  18  11
#
#          IP   TBF    H    R   ER  HR   BB  IBB  HBP  WP  BK   SO   GB   FB  \
# 0 598.00000  2488  537  244  219  69  206    4   27  17   2  629  706  579
# 1 600.00000  2483  511  253  236  65  193   13   19  19   1  639  673  650
# 2 619.00000  2578  517  257  245  68  224    6   31  28   1  591  791  590
# 3 609.20000  2558  511  267  244  77  228    1   40  14   6  602  746  627
# 4 586.00000  2437  504  258  245  72  215    4   26  21   3  567  717  595
#
#     LD  IFFB  Balls  Strikes  Pitches   RS  IFH  BU  BUH     K/9    BB/9  \
# 0  330    53   3634     6179     9813  304   45   9    2 9.47000 3.10000
# 1  286    61   3315     6380     9695  295   52  22    6 9.59000 2.90000
# 2  334    66   3543     6330     9873  395   48  15    6 8.59000 3.26000
# 3  300    66   3590     6412    10002  311   55  14    7 8.89000 3.37000
# 4  305    71   3637     6180     9817  280   38  12    7 8.71000 3.30000
#
#      K/BB     H/9    HR/9     AVG    WHIP   BABIP    LOB%     FIP   GB/FB  \
# 0 3.05000 8.08000 1.04000 0.23800 1.24000 0.30100 0.78100 3.84000 1.22000
# 1 3.31000 7.67000 0.98000 0.22500 1.17000 0.28500 0.74400 3.61000 1.04000
# 2 2.64000 7.52000 0.99000 0.22300 1.20000 0.27000 0.76100 4.03000 1.34000
# 3 2.64000 7.54000 1.14000 0.22300 1.21000 0.26900 0.76300 4.26000 1.19000
# 4 2.64000 7.74000 1.11000 0.23000 1.23000 0.27700 0.75600 4.17000 1.21000
#
#       LD%     GB%     FB%   IFFB%   HR/FB    IFH%    BUH%  Starting  Start-IP  \
# 0 0.20400 0.43700 0.35900 0.09200 0.11900 0.06400 0.22200  60.00000 377.00000
# 1 0.17800 0.41800 0.40400 0.09400 0.10000 0.07700 0.27300  75.60000 376.90000
# 2 0.19500 0.46100 0.34400 0.11200 0.11500 0.06100 0.40000  62.70000 323.30000
# 3 0.17900 0.44600 0.37500 0.10500 0.12300 0.07400 0.50000  30.40000 350.40000
# 4 0.18900 0.44300 0.36800 0.11900 0.12100 0.05300 0.58300  53.80000 354.60000
#
#    Relieving  Relief-IP      RAR     WAR Dollars    tERA    xFIP     WPA  \
# 0   24.60000  216.10000 84.60000 9.00000   $71.7 3.94000 3.88000 4.02000
# 1   14.80000  218.20000 90.40000 9.70000   $77.7 3.40000 3.93000 2.98000
# 2   -3.30000  288.00000 59.40000 6.50000   $52.3 3.87000 4.11000 2.46000
# 3   21.20000  256.70000 51.60000 5.40000   $43.5 4.08000 4.25000 4.33000
# 4   19.70000  226.50000 73.50000 7.50000   $60.1 3.93000 4.19000 0.04000
#
#        -WPA     +WPA     RE24     REW     pLI    inLI    gmLI    exLI  Pulls  \
# 0 -41.78000 45.80000 44.53000 4.71000 1.00000 0.93000 0.98000 1.02000    204
# 1 -41.94000 44.91000 40.78000 4.32000 1.01000 0.91000 1.09000 1.17000    197
# 2 -41.00000 43.45000 29.36000 3.06000 0.95000 0.85000 1.04000 1.09000    227
# 3 -42.74000 47.06000 28.54000 2.93000 1.01000 0.95000 1.19000 1.29000    213
# 4 -42.72000 42.76000 22.07000 2.32000 0.98000 0.92000 1.07000 1.13000    202
#
#    WPA/LI   Clutch   FB% 2      FBv     SL%      SLv     CT%      CTv     CB%  \
# 0 0.78000  3.24000 0.47800 94.10000 0.19100 83.80000 0.09200 88.00000 0.14200
# 1 4.69000 -1.74000 0.45000 93.90000 0.21200 84.20000 0.06500 89.10000 0.07700
# 2 1.99000  0.60000 0.44200 93.10000 0.20400 83.00000 0.11500 88.20000 0.09500
# 3 0.71000  3.56000 0.48500 94.80000 0.19200 85.10000 0.07400 89.40000 0.10600
# 4 1.37000 -1.33000 0.49500 93.80000 0.16000 82.50000 0.08900 88.20000 0.10100
#
#        CBv     CH%      CHv     SF%      SFv  KN%  KNv     XX%  PO%      wFB  \
# 0 79.80000 0.07900 87.30000 0.01800 85.90000  NaN  NaN 0.00400  NaN 17.90000
# 1 81.30000 0.12500 85.90000 0.07000 86.90000  NaN  NaN 0.00800  NaN 28.60000
# 2 80.20000 0.10200 86.80000 0.04200 86.60000  NaN  NaN 0.00400  NaN 15.20000
# 3 82.80000 0.14300 86.70000     NaN      NaN  NaN  NaN 0.00300  NaN 31.00000
# 4 79.00000 0.14100 84.50000 0.01500 86.80000  NaN  NaN 0.00400  NaN 24.30000
#
#       wSL      wCT      wCB      wCH      wSF  wKN   wFB/C   wSL/C  ...  \
# 0 8.40000  8.40000 13.30000 -8.30000 -2.60000  NaN 0.38000 0.45000  ...
# 1 1.70000  6.30000 -1.50000  9.60000 10.10000  NaN 0.66000 0.08000  ...
# 2 5.70000 11.10000  9.10000  0.80000  8.90000  NaN 0.35000 0.28000  ...
# 3 3.30000 -3.80000  2.00000 -1.20000      NaN  NaN 0.64000 0.17000  ...
# 4 4.70000 -1.10000  8.60000  7.20000 -0.30000  NaN 0.50000 0.30000  ...
#
#    SB% (pi)  SI% (pi)  SL% (pi)  XX% (pi)  vCH (pi)  vCS (pi)  vCU (pi)  \
# 0       NaN   0.11900   0.24900       NaN  87.40000       NaN  79.70000
# 1       NaN   0.07600   0.23300   0.00000  86.10000       NaN  81.40000
# 2       NaN   0.18400   0.25000       NaN  86.80000       NaN  81.20000
# 3       NaN   0.22500   0.21800       NaN  86.80000       NaN  83.20000
# 4   0.00400   0.15100   0.17700   0.00000  84.80000       NaN  79.30000
#
#    vFA (pi)  vFC (pi)  vFS (pi)  vKN (pi)  vSB (pi)  vSI (pi)  vSL (pi)  \
# 0  94.40000  86.90000  86.10000       NaN       NaN  94.10000  85.10000
# 1  94.00000  88.00000  84.30000       NaN       NaN  95.00000  84.80000
# 2  94.70000  88.40000  87.20000       NaN       NaN  91.60000  83.50000
# 3  94.70000  89.60000       NaN       NaN       NaN  95.30000  84.80000
# 4  94.10000  89.50000  89.30000       NaN  80.50000  94.10000  82.90000
#
#    vXX (pi)  CH-X (pi)  CS-X (pi)  CU-X (pi)  FA-X (pi)  FC-X (pi)  FS-X (pi)  \
# 0       NaN   -6.30000        NaN    3.10000   -3.90000    1.90000   -6.20000
# 1  77.20000   -6.00000        NaN    4.90000   -3.90000    1.80000   -7.20000
# 2       NaN    4.20000        NaN    2.70000    0.70000    1.70000   -5.30000
# 3       NaN   -5.70000        NaN    4.00000   -3.90000   -0.10000        NaN
# 4  95.20000   -3.30000        NaN    3.60000   -0.30000    1.20000   -4.20000
#
#    KN-X (pi)  SB-X (pi)  SI-X (pi)  SL-X (pi)  XX-X (pi)  CH-Z (pi)  \
# 0        NaN        NaN    1.20000    4.30000        NaN    2.50000
# 1        NaN        NaN   -8.10000    5.30000    0.00000    2.60000
# 2        NaN        NaN   -4.70000    2.90000        NaN    1.40000
# 3        NaN        NaN   -6.90000    3.40000        NaN    2.70000
# 4        NaN   -5.20000   -3.40000    3.40000   -9.90000    3.40000
#
#    CS-Z (pi)  CU-Z (pi)  FA-Z (pi)  FC-Z (pi)  FS-Z (pi)  KN-Z (pi)  \
# 0        NaN   -9.30000    8.80000    2.90000    0.00000        NaN
# 1        NaN   -8.40000    8.30000    2.10000    0.60000        NaN
# 2        NaN   -7.20000    9.10000    3.10000    3.00000        NaN
# 3        NaN   -4.10000    9.10000    3.70000        NaN        NaN
# 4        NaN   -9.70000    8.30000    4.40000    1.90000        NaN
#
#    SB-Z (pi)  SI-Z (pi)  SL-Z (pi)  XX-Z (pi)  wCH (pi)  wCS (pi)  wCU (pi)  \
# 0        NaN    4.00000    0.00000        NaN  -9.20000       NaN  12.00000
# 1        NaN    3.90000   -0.80000    0.00000  12.10000       NaN  -1.60000
# 2        NaN    1.20000   -0.10000        NaN   8.60000       NaN   8.70000
# 3        NaN    4.10000   -0.50000        NaN   0.20000       NaN   4.70000
# 4   -4.10000    5.60000    0.30000    6.90000   8.00000       NaN   7.60000
#
#    wFA (pi)  wFC (pi)  wFS (pi)  wKN (pi)  wSB (pi)  wSI (pi)  wSL (pi)  \
# 0   3.70000   4.20000  -2.60000       NaN       NaN  16.60000  16.20000
# 1  24.80000  13.40000   6.50000       NaN       NaN   8.80000  -3.30000
# 2  -3.40000   6.60000  -0.30000       NaN       NaN  24.80000  13.80000
# 3  10.00000   0.00000       NaN       NaN       NaN  24.30000  -1.00000
# 4   4.40000   1.00000   0.90000       NaN  -1.40000  22.80000   5.30000
#
#    wXX (pi)  wCH/C (pi)  wCS/C (pi)  wCU/C (pi)  wFA/C (pi)  wFC/C (pi)  \
# 0       NaN    -1.18000         NaN     0.88000     0.11000     0.87000
# 1   0.00000     1.04000         NaN    -0.23000     0.66000     2.90000
# 2       NaN     0.68000         NaN     1.15000    -0.13000     0.78000
# 3       NaN     0.01000         NaN     0.57000     0.39000    -0.01000
# 4   0.00000     0.58000         NaN     0.78000     0.13000     0.14000
#
#    wFS/C (pi)  wKN/C (pi)  wSB/C (pi)  wSI/C (pi)  wSL/C (pi)  wXX/C (pi)  \
# 0    -1.49000         NaN         NaN     1.42000     0.66000         NaN
# 1     1.07000         NaN         NaN     1.19000    -0.15000    -3.82000
# 2    -0.16000         NaN         NaN     1.38000     0.56000         NaN
# 3         NaN         NaN         NaN     1.08000    -0.04000         NaN
# 4     0.85000         NaN    -3.79000     1.53000     0.30000     4.40000
#
#    O-Swing% (pi)  Z-Swing% (pi)  Swing% (pi)  O-Contact% (pi)  \
# 0        0.29200        0.64700      0.47000          0.51400
# 1        0.31300        0.67200      0.49600          0.57000
# 2        0.28600        0.62700      0.46300          0.56300
# 3        0.28400        0.65100      0.47000          0.58600
# 4        0.28900        0.63700      0.46300          0.58200
#
#    Z-Contact% (pi)  Contact% (pi)  Zone% (pi)  Pace (pi)      FRM  K/9+  \
# 0          0.82900        0.73200     0.50200   19.00000 -7.80000   107
# 1          0.82500        0.74600     0.50800   18.70000  0.20000   109
# 2          0.84900        0.76300     0.51800   18.20000 -5.80000    98
# 3          0.84400        0.76700     0.50500   18.30000  8.90000   101
# 4          0.84000        0.76000     0.50100   18.60000 -3.90000   101
#
#    BB/9+  K/BB+  H/9+  HR/9+  AVG+  WHIP+  BABIP+  LOB%+  K%+  BB%+  LD%+  \
# 0     94    114    97     90    99     96     103    109  110    96   103
# 1     88    124    92     84    93     91      98    103  112    90    89
# 2     99     96    90     86    92     93      93    106  100   101    98
# 3    102     98    91     98    93     94      93    106  102   104    90
# 4     96    104    89     93    92     91      93    105  104    99    92
#
#    GB%+  FB%+  HR/FB%+  Pull%+  Cent%+  Oppo%+  Soft%+  Med%+  Hard%+  \
# 0   104    94      101      94     108      98     102     99     101
# 1   100   106       84      98     101     101      96    102      99
# 2   110    90       97     104      97      98     106     98     100
# 3   106    98      104     107     102      86     102    102      96
# 4   103   101       96     103     101      94     115    101      91
#
#         EV       LA  Barrels  Barrel%     maxEV  HardHit  HardHit%  Events  \
# 0 89.10000 11.30000      144  0.08900 117.40000      649   0.39900    1626
# 1 88.90000 14.00000      130  0.08000 116.00000      639   0.39200    1632
# 2 88.50000 10.50000      131  0.07600 115.90000      669   0.38600    1732
# 3 88.80000 12.50000      137  0.08100 116.70000      663   0.39300    1688
# 4 87.70000 12.50000      122  0.07500 114.60000      578   0.35500    1629
#
#     CStr%    CSW%  xERA
# 0 0.15800 0.28400   NaN
# 1 0.16100 0.28500   NaN
# 2 0.17800 0.28600   NaN
# 3 0.17000 0.27900   NaN
# 4 0.16600 0.27600   NaN
#
# [5 rows x 333 columns]

# %%
df.columns
# Out:
# Index(['teamIDfg', 'Season', 'Team', 'Age', 'W', 'L', 'ERA', 'G', 'GS', 'CG',
#        ...
#        'LA', 'Barrels', 'Barrel%', 'maxEV', 'HardHit', 'HardHit%', 'Events',
#        'CStr%', 'CSW%', 'xERA'],
#       dtype='object', length=333)

# %%
print("Pre removal ", df.shape)
#df = df.drop(['#days'], axis = 1)

print("Post removal ", df.shape)
# Out:
# Pre removal  (30, 333)
# Post removal  (30, 333)

# %%
df.columns
# Out:
# Index(['teamIDfg', 'Season', 'Team', 'Age', 'W', 'L', 'ERA', 'G', 'GS', 'CG',
#        ...
#        'LA', 'Barrels', 'Barrel%', 'maxEV', 'HardHit', 'HardHit%', 'Events',
#        'CStr%', 'CSW%', 'xERA'],
#       dtype='object', length=333)

# %%
# rename columns
#df = df.rename(columns = {'xyz': 'abc'})
#df.columns

# %%
# count nulls
counts = df.isna().sum()
percentages = round(df.isna().mean() * 100, 1)
null_values = pd.concat([counts, percentages], axis=1, keys=["count", "%"])
print(null_values)
# Out:
#                  count         %
# teamIDfg             0   0.00000
# Season               0   0.00000
# Team                 0   0.00000
# Age                  0   0.00000
# W                    0   0.00000
# L                    0   0.00000
# ERA                  0   0.00000
# G                    0   0.00000
# GS                   0   0.00000
# CG                   0   0.00000
# ShO                  0   0.00000
# SV                   0   0.00000
# BS                   0   0.00000
# IP                   0   0.00000
# TBF                  0   0.00000
# H                    0   0.00000
# R                    0   0.00000
# ER                   0   0.00000
# HR                   0   0.00000
# BB                   0   0.00000
# IBB                  0   0.00000
# HBP                  0   0.00000
# WP                   0   0.00000
# BK                   0   0.00000
# SO                   0   0.00000
# GB                   0   0.00000
# FB                   0   0.00000
# LD                   0   0.00000
# IFFB                 0   0.00000
# Balls                0   0.00000
# Strikes              0   0.00000
# Pitches              0   0.00000
# RS                   0   0.00000
# IFH                  0   0.00000
# BU                   0   0.00000
# BUH                  0   0.00000
# K/9                  0   0.00000
# BB/9                 0   0.00000
# K/BB                 0   0.00000
# H/9                  0   0.00000
# HR/9                 0   0.00000
# AVG                  0   0.00000
# WHIP                 0   0.00000
# BABIP                0   0.00000
# LOB%                 0   0.00000
# FIP                  0   0.00000
# GB/FB                0   0.00000
# LD%                  0   0.00000
# GB%                  0   0.00000
# FB%                  0   0.00000
# IFFB%                0   0.00000
# HR/FB                0   0.00000
# IFH%                 0   0.00000
# BUH%                 0   0.00000
# Starting             0   0.00000
# Start-IP             0   0.00000
# Relieving            0   0.00000
# Relief-IP            0   0.00000
# RAR                  0   0.00000
# WAR                  0   0.00000
# Dollars              0   0.00000
# tERA                 0   0.00000
# xFIP                 0   0.00000
# WPA                  0   0.00000
# -WPA                 0   0.00000
# +WPA                 0   0.00000
# RE24                 0   0.00000
# REW                  0   0.00000
# pLI                  0   0.00000
# inLI                 0   0.00000
# gmLI                 0   0.00000
# exLI                 0   0.00000
# Pulls                0   0.00000
# WPA/LI               0   0.00000
# Clutch               0   0.00000
# FB% 2                0   0.00000
# FBv                  0   0.00000
# SL%                  0   0.00000
# SLv                  0   0.00000
# CT%                  0   0.00000
# CTv                  0   0.00000
# CB%                  0   0.00000
# CBv                  0   0.00000
# CH%                  0   0.00000
# CHv                  0   0.00000
# SF%                  1   3.30000
# SFv                  1   3.30000
# KN%                 27  90.00000
# KNv                 27  90.00000
# XX%                  0   0.00000
# PO%                 30 100.00000
# wFB                  0   0.00000
# wSL                  0   0.00000
# wCT                  0   0.00000
# wCB                  0   0.00000
# wCH                  0   0.00000
# wSF                  1   3.30000
# wKN                 27  90.00000
# wFB/C                0   0.00000
# wSL/C                0   0.00000
# wCT/C                0   0.00000
# wCB/C                0   0.00000
# wCH/C                0   0.00000
# wSF/C                1   3.30000
# wKN/C               27  90.00000
# O-Swing%             0   0.00000
# Z-Swing%             0   0.00000
# Swing%               0   0.00000
# O-Contact%           0   0.00000
# Z-Contact%           0   0.00000
# Contact%             0   0.00000
# Zone%                0   0.00000
# F-Strike%            0   0.00000
# SwStr%               0   0.00000
# HLD                  0   0.00000
# SD                   0   0.00000
# MD                   0   0.00000
# ERA-                 0   0.00000
# FIP-                 0   0.00000
# xFIP-                0   0.00000
# K%                   0   0.00000
# BB%                  0   0.00000
# SIERA                0   0.00000
# RS/9                 0   0.00000
# E-F                  0   0.00000
# FA% (sc)             0   0.00000
# FT% (sc)            30 100.00000
# FC% (sc)             0   0.00000
# FS% (sc)             5  16.70000
# FO% (sc)            28  93.30000
# SI% (sc)             0   0.00000
# SL% (sc)             0   0.00000
# CU% (sc)             0   0.00000
# KC% (sc)             5  16.70000
# EP% (sc)            15  50.00000
# CH% (sc)             0   0.00000
# SC% (sc)            29  96.70000
# KN% (sc)            30 100.00000
# UN% (sc)            30 100.00000
# vFA (sc)             0   0.00000
# vFT (sc)            30 100.00000
# vFC (sc)             0   0.00000
# vFS (sc)             5  16.70000
# vFO (sc)            28  93.30000
# vSI (sc)             0   0.00000
# vSL (sc)             0   0.00000
# vCU (sc)             0   0.00000
# vKC (sc)             5  16.70000
# vEP (sc)            15  50.00000
# vCH (sc)             0   0.00000
# vSC (sc)            29  96.70000
# vKN (sc)            30 100.00000
# FA-X (sc)            0   0.00000
# FT-X (sc)           30 100.00000
# FC-X (sc)            0   0.00000
# FS-X (sc)            5  16.70000
# FO-X (sc)           28  93.30000
# SI-X (sc)            0   0.00000
# SL-X (sc)            0   0.00000
# CU-X (sc)            0   0.00000
# KC-X (sc)            5  16.70000
# EP-X (sc)           15  50.00000
# CH-X (sc)            0   0.00000
# SC-X (sc)           29  96.70000
# KN-X (sc)           30 100.00000
# FA-Z (sc)            0   0.00000
# FT-Z (sc)           30 100.00000
# FC-Z (sc)            0   0.00000
# FS-Z (sc)            5  16.70000
# FO-Z (sc)           28  93.30000
# SI-Z (sc)            0   0.00000
# SL-Z (sc)            0   0.00000
# CU-Z (sc)            0   0.00000
# KC-Z (sc)            5  16.70000
# EP-Z (sc)           15  50.00000
# CH-Z (sc)            0   0.00000
# SC-Z (sc)           29  96.70000
# KN-Z (sc)           30 100.00000
# wFA (sc)             0   0.00000
# wFT (sc)            30 100.00000
# wFC (sc)             0   0.00000
# wFS (sc)             5  16.70000
# wFO (sc)            28  93.30000
# wSI (sc)             0   0.00000
# wSL (sc)             0   0.00000
# wCU (sc)             0   0.00000
# wKC (sc)             5  16.70000
# wEP (sc)            15  50.00000
# wCH (sc)             0   0.00000
# wSC (sc)            29  96.70000
# wKN (sc)            30 100.00000
# wFA/C (sc)           0   0.00000
# wFT/C (sc)          30 100.00000
# wFC/C (sc)           0   0.00000
# wFS/C (sc)           5  16.70000
# wFO/C (sc)          28  93.30000
# wSI/C (sc)           0   0.00000
# wSL/C (sc)           0   0.00000
# wCU/C (sc)           0   0.00000
# wKC/C (sc)           5  16.70000
# wEP/C (sc)          15  50.00000
# wCH/C (sc)           0   0.00000
# wSC/C (sc)          29  96.70000
# wKN/C (sc)          30 100.00000
# O-Swing% (sc)        0   0.00000
# Z-Swing% (sc)        0   0.00000
# Swing% (sc)          0   0.00000
# O-Contact% (sc)      0   0.00000
# Z-Contact% (sc)      0   0.00000
# Contact% (sc)        0   0.00000
# Zone% (sc)           0   0.00000
# Pace                 0   0.00000
# RA9-WAR              0   0.00000
# BIP-Wins             0   0.00000
# LOB-Wins             0   0.00000
# FDP-Wins             0   0.00000
# Age Rng              0   0.00000
# K-BB%                0   0.00000
# Pull%                0   0.00000
# Cent%                0   0.00000
# Oppo%                0   0.00000
# Soft%                0   0.00000
# Med%                 0   0.00000
# Hard%                0   0.00000
# kwERA                0   0.00000
# TTO%                 0   0.00000
# CH% (pi)             0   0.00000
# CS% (pi)            27  90.00000
# CU% (pi)             0   0.00000
# FA% (pi)             0   0.00000
# FC% (pi)             0   0.00000
# FS% (pi)             1   3.30000
# KN% (pi)            30 100.00000
# SB% (pi)            29  96.70000
# SI% (pi)             0   0.00000
# SL% (pi)             0   0.00000
# XX% (pi)            12  40.00000
# vCH (pi)             0   0.00000
# vCS (pi)            27  90.00000
# vCU (pi)             0   0.00000
# vFA (pi)             0   0.00000
# vFC (pi)             0   0.00000
# vFS (pi)             1   3.30000
# vKN (pi)            30 100.00000
# vSB (pi)            29  96.70000
# vSI (pi)             0   0.00000
# vSL (pi)             0   0.00000
# vXX (pi)            12  40.00000
# CH-X (pi)            0   0.00000
# CS-X (pi)           27  90.00000
# CU-X (pi)            0   0.00000
# FA-X (pi)            0   0.00000
# FC-X (pi)            0   0.00000
# FS-X (pi)            1   3.30000
# KN-X (pi)           30 100.00000
# SB-X (pi)           29  96.70000
# SI-X (pi)            0   0.00000
# SL-X (pi)            0   0.00000
# XX-X (pi)           12  40.00000
# CH-Z (pi)            0   0.00000
# CS-Z (pi)           27  90.00000
# CU-Z (pi)            0   0.00000
# FA-Z (pi)            0   0.00000
# FC-Z (pi)            0   0.00000
# FS-Z (pi)            1   3.30000
# KN-Z (pi)           30 100.00000
# SB-Z (pi)           29  96.70000
# SI-Z (pi)            0   0.00000
# SL-Z (pi)            0   0.00000
# XX-Z (pi)           12  40.00000
# wCH (pi)             0   0.00000
# wCS (pi)            27  90.00000
# wCU (pi)             0   0.00000
# wFA (pi)             0   0.00000
# wFC (pi)             0   0.00000
# wFS (pi)             1   3.30000
# wKN (pi)            30 100.00000
# wSB (pi)            29  96.70000
# wSI (pi)             0   0.00000
# wSL (pi)             0   0.00000
# wXX (pi)            12  40.00000
# wCH/C (pi)           0   0.00000
# wCS/C (pi)          27  90.00000
# wCU/C (pi)           0   0.00000
# wFA/C (pi)           0   0.00000
# wFC/C (pi)           0   0.00000
# wFS/C (pi)           1   3.30000
# wKN/C (pi)          30 100.00000
# wSB/C (pi)          29  96.70000
# wSI/C (pi)           0   0.00000
# wSL/C (pi)           0   0.00000
# wXX/C (pi)          12  40.00000
# O-Swing% (pi)        0   0.00000
# Z-Swing% (pi)        0   0.00000
# Swing% (pi)          0   0.00000
# O-Contact% (pi)      0   0.00000
# Z-Contact% (pi)      0   0.00000
# Contact% (pi)        0   0.00000
# Zone% (pi)           0   0.00000
# Pace (pi)            0   0.00000
# FRM                  0   0.00000
# K/9+                 0   0.00000
# BB/9+                0   0.00000
# K/BB+                0   0.00000
# H/9+                 0   0.00000
# HR/9+                0   0.00000
# AVG+                 0   0.00000
# WHIP+                0   0.00000
# BABIP+               0   0.00000
# LOB%+                0   0.00000
# K%+                  0   0.00000
# BB%+                 0   0.00000
# LD%+                 0   0.00000
# GB%+                 0   0.00000
# FB%+                 0   0.00000
# HR/FB%+              0   0.00000
# Pull%+               0   0.00000
# Cent%+               0   0.00000
# Oppo%+               0   0.00000
# Soft%+               0   0.00000
# Med%+                0   0.00000
# Hard%+               0   0.00000
# EV                   0   0.00000
# LA                   0   0.00000
# Barrels              0   0.00000
# Barrel%              0   0.00000
# maxEV                0   0.00000
# HardHit              0   0.00000
# HardHit%             0   0.00000
# Events               0   0.00000
# CStr%                0   0.00000
# CSW%                 0   0.00000
# xERA                30 100.00000

# %%
# drop nulls
print("Pre removal ", df.shape)
#df = df.dropna()
print("Post removal ", df.shape)
# Out:
# Pre removal  (30, 333)
# Post removal  (30, 333)

# %%
# count duplicates
len(df['Team'])-len(df['Team'].drop_duplicates())
# Out:
# 0

# %%
# remove dups

print("Pre removal ", df.shape)
#df = df.drop_duplicates(subset=['Name'])
print("Post removal ", df.shape)
# Out:
# Pre removal  (30, 333)
# Post removal  (30, 333)

# %%
# remove outliers

#print("Pre removal ", df.shape)
#df = df[(np.abs(stats.zscore(df['xyz'])) < 3)]
#print("Post removal ", df.shape)

# %% [markdown]
# # Data Restructing

# %% [markdown]
# ## Variable Restructing

# %% [markdown]
# ### Level

# %%
# change column values
#df['Lev'] = df['Lev'].map({'Maj-AL': 'AL', 'Maj-NL': 'NL'})

# %%
# rename column
#df.rename(columns={'Lev': 'League'}, inplace=True)

# %%
# verify changes
#df[["League", "Name"]].groupby("League").count()

# %% [markdown]
# ## Normalizations

# %%
#df=['Volume_norm'] = (df.Volume - df.Volume.mean()) / (df.Volume.max() - df.Volume.mix())
#df.columns

# %% [markdown]
# ## Categorizations

# %%
#normalized = ['Volume_norm', 'Difficulty_norm']

# %% [markdown]
# ## Calculations

# %%
#calculate wOBA on 14 day player batting

#df['wOBA'] = (0.69*df['BB'] + 0.72*df['HBP'] + 0.89*df['H'] + 1.27*df['2B'] + 1.62*df['3B'] + 2.10*df['HR']) / (df['AB'] + df['BB'] - df['IBB'] + df['SF'] + df['HBP'])

# %%
#df.head()

# %% [markdown]
# ## Export Data

# %%
#EXPORT

df.to_csv('C:\\Users\\b7tbu\\JUPYTER PROJECTS\\ANALYTICO\\Data_Exports\\Team\\Pitching\\EXPORT_annual.csv', index=False)
